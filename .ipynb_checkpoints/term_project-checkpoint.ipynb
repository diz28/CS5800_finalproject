# %%
import pandas as pd
import json

df_csv = pd.read_csv('UNSPSC_English.csv')
df_xlsx = pd.read_excel('Avalara_goods_and_services.xlsx')
# Out:
# /tmp/ipykernel_143546/4190874567.py:4: DtypeWarning: Columns (1,2,5,8,9,12,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_csv = pd.read_csv('UNSPSC_English.csv')

# %%
df_xlsx = df_xlsx.rename(columns={'Unnamed: 0':'AvaTax System Tax Code', 'AvaTax System Tax Codes':'AvaTax System Tax Code Description',
                                 'Unnamed: 2':'Additional AvaTax System Tax Code Information'})
df_xlsx = df_xlsx[2:200]
df_xlsx
# Out:
#     AvaTax System Tax Code                 AvaTax System Tax Code Description  \
# 2                 D0000000                                      Digital goods
# 3                 D9999999  Temporary unmapped digital goods sku - taxable...
# 4                 DA010000  Digital goods: advertising material (digital o...
# 5                 DA030000  Digital goods: art (digital only -- no physica...
# 6                 DA040000  Digital goods: audio (digital only -- no physi...
# ..                     ...                                                ...
# 195               PA020662                        Food producing woody plants
# 196               PA020664  Insecticides / fungicides for food producing p...
# 197               PA020665                                       Flower seeds
# 198               PA020668  Dual-purpose fertilizer: non-food producing pl...
# 199               PA021078   Food producing plants (vegetable / herb / fruit)
#
#          Additional AvaTax System Tax Code Information
# 2    Digital goods are generally viewed as download...
# 3    A digital good that has not been mapped to a s...
# 4    Tangible personal property (i.e. designs, artw...
# 5    Canned artwork that is transferred to the cust...
# 6    Audio (i.e. music or spoken word) that is tran...
# ..                                                 ...
# 195  Includes: blueberry and raspberry bush / apple...
# 196                                                NaN
# 197                             Excludes flower bulbs.
# 198              Primarily fertilizes and kills weeds.
# 199                                                NaN
#
# [198 rows x 3 columns]

# %%
# import nltk and download resources
import nltk
import ssl
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /home/diz/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/diz/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# parse the stop words and special characters out
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))
stop_words.add(':')
stop_words.add('--')
stop_words.add('-')
stop_words.add('(')
stop_words.add(')')
stop_words.add('/')
stop_words.add('*')
stop_words.add(';')
stop_words.add('.')
stop_words.add('i.e')
stop_words.add('A')
stop_words.add('a')
stop_words.add(',')

# %%
def createParsedColumns(file, col1, col2, start_index, new_col):
    for index1, description1 in enumerate(file[col1], start_index):
        if not pd.isna(description1):
            word_tokens1 = word_tokenize(description1)

            filtered_sentence1 = []
            for w1 in word_tokens1:
                if w1 not in stop_words:
                    filtered_sentence1.append(w1.lower())

            # remove empty strings
            while "" in filtered_sentence1:
                filtered_sentence1.remove("")

            # updating record in col1
            file.at[index1, col1]= ','.join(filtered_sentence1)
        else:
            file.at[index1, col1]= ''

    for index2, description2 in enumerate(file[col2], start_index):
        if not pd.isna(description2):
            word_tokens2 = word_tokenize(description2)

            filtered_sentence2 = []
            for w2 in word_tokens2:
                if w2 not in stop_words:
                    filtered_sentence2.append(w2.lower())

            # remove empty strings
            while "" in filtered_sentence2:
                filtered_sentence2.remove("")

            # updating record in col2
            file.at[index2, col2]= ','.join(filtered_sentence2)
        else:
            file.at[index2, col2]= ''

    # create 3rd column
    new_column_series = []
    for index3, description3 in enumerate(file[col2], start_index):
        temp1 = file[col1].loc[index3].split(',')

        if not pd.isna(description3):
            temp2 = file[col2].loc[index3].split(',')
            temp3 = temp1 + temp2
            temp3 = set(temp3)

            if '' in temp3:
                temp3.remove('')

            new_column_series.append(list(temp3))
        else:
            new_column_series.append(list(temp1))

    # insert new column
    file.loc[:,new_col] = new_column_series

# %%
column_name = 'AvaTax System Tax Code Description'
column_name_2 = 'Additional AvaTax System Tax Code Information'
new_col_name = 'tax_parsed'
createParsedColumns(df_xlsx, column_name, column_name_2, 2, new_col_name)
df_xlsx
# Out:
#     AvaTax System Tax Code                 AvaTax System Tax Code Description  \
# 2                 D0000000                                      digital,goods
# 3                 D9999999  temporary,unmapped,digital,goods,sku,taxable,d...
# 4                 DA010000  digital,goods,advertising,material,digital,phy...
# 5                 DA030000           digital,goods,art,digital,physical,media
# 6                 DA040000         digital,goods,audio,digital,physical,media
# ..                     ...                                                ...
# 195               PA020662                        food,producing,woody,plants
# 196               PA020664      insecticides,fungicides,food,producing,plants
# 197               PA020665                                       flower,seeds
# 198               PA020668  dual-purpose,fertilizer,non-food,producing,pla...
# 199               PA021078         food,producing,plants,vegetable,herb,fruit
#
#          Additional AvaTax System Tax Code Information  \
# 2    digital,goods,generally,viewed,downloadable,it...
# 3    digital,good,mapped,specific,digital,good,tax,...
# 4    tangible,personal,property,designs,artwork,pho...
# 5    canned,artwork,transferred,customer,electronic...
# 6    audio,music,spoken,word,transferred,customer,e...
# ..                                                 ...
# 195  includes,blueberry,raspberry,bush,apple,pear,t...
# 196
# 197                              excludes,flower,bulbs
# 198                   primarily,fertilizes,kills,weeds
# 199
#
#                                             tax_parsed
# 2    [transferred, computer, software, photographs,...
# 3    [limited, unmapped, cases, mapped, temporary, ...
# 4    [property, designs, transferred, means, tangib...
# 5    [goods, digital, transferred, canned, customer...
# 6    [audio, goods, digital, spoken, transferred, m...
# ..                                                 ...
# 195  [includes, woody, food, raspberry, pear, ornam...
# 196  [food, plants, producing, insecticides, fungic...
# 197                   [flower, excludes, bulbs, seeds]
# 198  [herbicide, w/, plants, fertilizer, non-food, ...
# 199  [food, vegetable, plants, herb, producing, fruit]
#
# [198 rows x 4 columns]

# %%
tc_hash_map = {}

new_col_name = 'tax_parsed'

for index, tax_code in enumerate(df_xlsx['AvaTax System Tax Code'], 2):

    # if tax_code = NaN
    if isinstance(tax_code, float):
        prefix = df_xlsx["AvaTax System Tax Code"].loc[index + 1]
        level_1 = prefix[0:2]
        level_2 = prefix[2:4]
        level_3 = "0000"
        df_xlsx["AvaTax System Tax Code"].loc[index] = prefix[0:4]+"0000"
    else:
        level_1 = tax_code[0:2]
        level_2 = tax_code[2:4]
        level_3 = tax_code[4:8]
    

    if level_1 not in tc_hash_map:
        temp_dict0 = {level_3: df_xlsx[new_col_name].loc[index]}
        temp_dict = {level_2: [df_xlsx[new_col_name].loc[index], temp_dict0]}
        tc_hash_map[level_1] = [df_xlsx[new_col_name].loc[index], temp_dict]
    elif level_2 not in tc_hash_map[level_1][1]:
        temp_dict0 = {level_3: df_xlsx[new_col_name].loc[index]}
        tc_hash_map[level_1][1][level_2] = [df_xlsx[new_col_name].loc[index], temp_dict0]
    elif level_3 not in tc_hash_map[level_1][1][level_2][1]:
        tc_hash_map[level_1][1][level_2][1][level_3] = df_xlsx[new_col_name].loc[index]

print(json.dumps(tc_hash_map, sort_keys=True, indent=2))
# Out:
# {
#   "D0": [
#     [
#       "transferred",
#       "computer",
#       "software",
#       "photographs",
#       "otherwise",
#       "music",
#       "sold",
#       "goods",
#       "digital",
#       "viewed",
#       "include",
#       "would",
#       "electronically",
#       "files",
#       "pdfs",
#       "artwork",
#       "movies",
#       "generally",
#       "websites",
#       "e-books",
#       "downloadable",
#       "items",
#       "examples",
#       "zip"
#     ],
#     {
#       "00": [
#         [
#           "transferred",
#           "computer",
#           "software",
#           "photographs",
#           "otherwise",
#           "music",
#           "sold",
#           "goods",
#           "digital",
#           "viewed",
#           "include",
#           "would",
#           "electronically",
#           "files",
#           "pdfs",
#           "artwork",
#           "movies",
#           "generally",
#           "websites",
#           "e-books",
#           "downloadable",
#           "items",
#           "examples",
#           "zip"
#         ],
#         {
#           "0000": [
#             "transferred",
#             "computer",
#             "software",
#             "photographs",
#             "otherwise",
#             "music",
#             "sold",
#             "goods",
#             "digital",
#             "viewed",
#             "include",
#             "would",
#             "electronically",
#             "files",
#             "pdfs",
#             "artwork",
#             "movies",
#             "generally",
#             "websites",
#             "e-books",
#             "downloadable",
#             "items",
#             "examples",
#             "zip"
#           ]
#         }
#       ]
#     }
#   ],
#   "D9": [
#     [
#       "limited",
#       "unmapped",
#       "cases",
#       "mapped",
#       "temporary",
#       "goods",
#       "digital",
#       "taxable",
#       "applicable",
#       "tax",
#       "system",
#       "base",
#       "specific",
#       "using",
#       "sku",
#       "use",
#       "accurately",
#       "assigned",
#       "unless",
#       "impose",
#       "adequately",
#       "exemption",
#       "purpose",
#       "reviewed",
#       "good",
#       "getting",
#       "entity",
#       "default",
#       "code"
#     ],
#     {
#       "99": [
#         [
#           "limited",
#           "unmapped",
#           "cases",
#           "mapped",
#           "temporary",
#           "goods",
#           "digital",
#           "taxable",
#           "applicable",
#           "tax",
#           "system",
#           "base",
#           "specific",
#           "using",
#           "sku",
#           "use",
#           "accurately",
#           "assigned",
#           "unless",
#           "impose",
#           "adequately",
#           "exemption",
#           "purpose",
#           "reviewed",
#           "good",
#           "getting",
#           "entity",
#           "default",
#           "code"
#         ],
#         {
#           "9999": [
#             "limited",
#             "unmapped",
#             "cases",
#             "mapped",
#             "temporary",
#             "goods",
#             "digital",
#             "taxable",
#             "applicable",
#             "tax",
#             "system",
#             "base",
#             "specific",
#             "using",
#             "sku",
#             "use",
#             "accurately",
#             "assigned",
#             "unless",
#             "impose",
#             "adequately",
#             "exemption",
#             "purpose",
#             "reviewed",
#             "good",
#             "getting",
#             "entity",
#             "default",
#             "code"
#           ]
#         }
#       ]
#     }
#   ],
#   "DA": [
#     [
#       "property",
#       "designs",
#       "transferred",
#       "means",
#       "tangible",
#       "advertising",
#       "goods",
#       "digital",
#       "etc",
#       "customer",
#       "services",
#       "associated",
#       "personal",
#       "artwork",
#       "media",
#       "photos",
#       "physical",
#       "material",
#       "electronic"
#     ],
#     {
#       "01": [
#         [
#           "property",
#           "designs",
#           "transferred",
#           "means",
#           "tangible",
#           "advertising",
#           "goods",
#           "digital",
#           "etc",
#           "customer",
#           "services",
#           "associated",
#           "personal",
#           "artwork",
#           "media",
#           "photos",
#           "physical",
#           "material",
#           "electronic"
#         ],
#         {
#           "0000": [
#             "property",
#             "designs",
#             "transferred",
#             "means",
#             "tangible",
#             "advertising",
#             "goods",
#             "digital",
#             "etc",
#             "customer",
#             "services",
#             "associated",
#             "personal",
#             "artwork",
#             "media",
#             "photos",
#             "physical",
#             "material",
#             "electronic"
#           ]
#         }
#       ],
#       "03": [
#         [
#           "goods",
#           "digital",
#           "transferred",
#           "canned",
#           "customer",
#           "artwork",
#           "art",
#           "means",
#           "electronic",
#           "media",
#           "physical"
#         ],
#         {
#           "0000": [
#             "goods",
#             "digital",
#             "transferred",
#             "canned",
#             "customer",
#             "artwork",
#             "art",
#             "means",
#             "electronic",
#             "media",
#             "physical"
#           ]
#         }
#       ],
#       "04": [
#         [
#           "audio",
#           "goods",
#           "digital",
#           "spoken",
#           "transferred",
#           "means",
#           "customer",
#           "electronic",
#           "media",
#           "word",
#           "physical",
#           "music"
#         ],
#         {
#           "0000": [
#             "audio",
#             "goods",
#             "digital",
#             "spoken",
#             "transferred",
#             "means",
#             "customer",
#             "electronic",
#             "media",
#             "word",
#             "physical",
#             "music"
#           ],
#           "0100": [
#             "satellite",
#             "subscriptions",
#             "services",
#             "radio"
#           ]
#         }
#       ],
#       "05": [
#         [
#           "audio",
#           "digital",
#           "works"
#         ],
#         {
#           "0000": [
#             "audio",
#             "digital",
#             "works"
#           ],
#           "1011": [
#             "rights",
#             "audio",
#             "digital",
#             "use",
#             "user",
#             "end",
#             "works",
#             "permanent",
#             "sold"
#           ],
#           "1012": [
#             "audio",
#             "digital",
#             "payments",
#             "works",
#             "continued",
#             "conditioned",
#             "rights"
#           ],
#           "1013": [
#             "audio",
#             "digital",
#             "user",
#             "end",
#             "works",
#             "users",
#             "sold"
#           ],
#           "9399": [
#             "audio",
#             "digital",
#             "use",
#             "works",
#             "permanent",
#             "less",
#             "rights"
#           ]
#         }
#       ]
#     }
#   ],
#   "DB": [
#     [
#       "goods",
#       "digital",
#       "transferred",
#       "means",
#       "customer",
#       "blueprints",
#       "electronic",
#       "media",
#       "physical"
#     ],
#     {
#       "01": [
#         [
#           "goods",
#           "digital",
#           "transferred",
#           "means",
#           "customer",
#           "blueprints",
#           "electronic",
#           "media",
#           "physical"
#         ],
#         {
#           "0000": [
#             "goods",
#             "digital",
#             "transferred",
#             "means",
#             "customer",
#             "blueprints",
#             "electronic",
#             "media",
#             "physical"
#           ]
#         }
#       ],
#       "02": [
#         [
#           "goods",
#           "digital",
#           "transferred",
#           "means",
#           "customer",
#           "electronic",
#           "media",
#           "physical",
#           "books"
#         ],
#         {
#           "0000": [
#             "goods",
#             "digital",
#             "transferred",
#             "means",
#             "customer",
#             "electronic",
#             "media",
#             "physical",
#             "books"
#           ]
#         }
#       ],
#       "03": [
#         [
#           "digital",
#           "books"
#         ],
#         {
#           "1000": [
#             "digital",
#             "books"
#           ],
#           "1013": [
#             "rights",
#             "digital",
#             "use",
#             "user",
#             "end",
#             "permanent",
#             "books",
#             "sold"
#           ],
#           "1014": [
#             "digital",
#             "use",
#             "books",
#             "permanent",
#             "less",
#             "rights"
#           ],
#           "1015": [
#             "digital",
#             "books",
#             "payments",
#             "continued",
#             "conditioned",
#             "rights"
#           ],
#           "1016": [
#             "digital",
#             "user",
#             "books",
#             "end",
#             "users",
#             "sold"
#           ]
#         }
#       ]
#     }
#   ],
#   "DC": [
#     [
#       "user",
#       "transferred",
#       "non-business",
#       "load",
#       "computer",
#       "software",
#       "sold",
#       "business-to-business",
#       "forms",
#       "end",
#       "operation",
#       "customer",
#       "electronically",
#       "various",
#       "``",
#       "either",
#       "media",
#       "leave",
#       "physical",
#       "business",
#       "''"
#     ],
#     {
#       "01": [
#         [
#           "user",
#           "transferred",
#           "non-business",
#           "load",
#           "computer",
#           "software",
#           "sold",
#           "business-to-business",
#           "forms",
#           "end",
#           "operation",
#           "customer",
#           "electronically",
#           "various",
#           "``",
#           "either",
#           "media",
#           "leave",
#           "physical",
#           "business",
#           "''"
#         ],
#         {
#           "0000": [
#             "user",
#             "transferred",
#             "non-business",
#             "load",
#             "computer",
#             "software",
#             "sold",
#             "business-to-business",
#             "forms",
#             "end",
#             "operation",
#             "customer",
#             "electronically",
#             "various",
#             "``",
#             "either",
#             "media",
#             "leave",
#             "physical",
#             "business",
#             "''"
#           ],
#           "0100": [
#             "deemed",
#             "transferred",
#             "canned",
#             "computer",
#             "software",
#             "written",
#             "minor",
#             "business-to-business",
#             "customized",
#             "custom",
#             "customer",
#             "modification",
#             "individual",
#             "specifications",
#             "media",
#             "merely",
#             "physical",
#             "'s",
#             "add-on"
#           ],
#           "0200": [
#             "deemed",
#             "transferred",
#             "canned",
#             "computer",
#             "software",
#             "form",
#             "written",
#             "minor",
#             "business-to-business",
#             "customized",
#             "custom",
#             "customer",
#             "modification",
#             "electronically",
#             "individual",
#             "downloaded",
#             "specifications",
#             "media",
#             "merely",
#             "physical",
#             "rather",
#             "'s",
#             "add-on"
#           ],
#           "0300": [
#             "deemed",
#             "canned",
#             "load",
#             "computer",
#             "software",
#             "written",
#             "minor",
#             "business-to-business",
#             "on-site",
#             "customized",
#             "custom",
#             "customer",
#             "modification",
#             "individual",
#             "specifications",
#             "media",
#             "leave",
#             "merely",
#             "actual",
#             "physical",
#             "'s",
#             "left",
#             "loaded",
#             "add-on"
#           ],
#           "0400": [
#             "business-to-business",
#             "customized",
#             "transferred",
#             "computer",
#             "software",
#             "media",
#             "prewritten/canned",
#             "physical"
#           ],
#           "0500": [
#             "business-to-business",
#             "customized",
#             "downloaded",
#             "transferred",
#             "computer",
#             "software",
#             "prewritten/canned",
#             "electronically"
#           ],
#           "0600": [
#             "via",
#             "business-to-business",
#             "'s",
#             "on-site",
#             "left",
#             "customized",
#             "loaded",
#             "customer",
#             "load",
#             "computer",
#             "software",
#             "prewritten/canned",
#             "leave",
#             "media",
#             "delivered",
#             "actual",
#             "physical"
#           ],
#           "1000": [
#             "e.g",
#             "'s",
#             "systems",
#             "operating",
#             "operation",
#             "integral",
#             "computer",
#             "software",
#             "system"
#           ]
#         }
#       ],
#       "02": [
#         [
#           "user",
#           "transferred",
#           "non-business",
#           "load",
#           "computer",
#           "software",
#           "sold",
#           "forms",
#           "business-to-customer",
#           "end",
#           "customer",
#           "electronically",
#           "various",
#           "``",
#           "either",
#           "media",
#           "leave",
#           "physical",
#           "business",
#           "''"
#         ],
#         {
#           "0000": [
#             "user",
#             "transferred",
#             "non-business",
#             "load",
#             "computer",
#             "software",
#             "sold",
#             "forms",
#             "business-to-customer",
#             "end",
#             "customer",
#             "electronically",
#             "various",
#             "``",
#             "either",
#             "media",
#             "leave",
#             "physical",
#             "business",
#             "''"
#           ],
#           "0100": [
#             "deemed",
#             "transferred",
#             "canned",
#             "computer",
#             "software",
#             "written",
#             "minor",
#             "customized",
#             "business-to-customer",
#             "custom",
#             "customer",
#             "modification",
#             "individual",
#             "specifications",
#             "media",
#             "merely",
#             "physical",
#             "'s",
#             "add-on"
#           ],
#           "0200": [
#             "deemed",
#             "transferred",
#             "canned",
#             "computer",
#             "software",
#             "form",
#             "written",
#             "minor",
#             "customized",
#             "business-to-customer",
#             "custom",
#             "customer",
#             "modification",
#             "electronically",
#             "individual",
#             "downloaded",
#             "specifications",
#             "media",
#             "merely",
#             "physical",
#             "rather",
#             "'s",
#             "add-on"
#           ],
#           "0300": [
#             "deemed",
#             "canned",
#             "load",
#             "computer",
#             "software",
#             "written",
#             "minor",
#             "on-site",
#             "customized",
#             "business-to-customer",
#             "custom",
#             "customer",
#             "modification",
#             "individual",
#             "specifications",
#             "media",
#             "leave",
#             "merely",
#             "actual",
#             "physical",
#             "'s",
#             "left",
#             "loaded",
#             "add-on"
#           ],
#           "0400": [
#             "customized",
#             "business-to-customer",
#             "transferred",
#             "computer",
#             "software",
#             "media",
#             "prewritten/canned",
#             "physical"
#           ],
#           "0402": [
#             "educational",
#             "business-to-business",
#             "way",
#             "customized",
#             "transferred",
#             "non-educational",
#             "primarily",
#             "academic",
#             "computer",
#             "software",
#             "prewritten/canned",
#             "media",
#             "purposes",
#             "designed",
#             "physical",
#             "something"
#           ],
#           "0500": [
#             "customized",
#             "downloaded",
#             "business-to-customer",
#             "transferred",
#             "computer",
#             "software",
#             "prewritten/canned",
#             "electronically"
#           ],
#           "0501": [
#             "educational",
#             "business-to-business",
#             "customized",
#             "downloaded",
#             "transferred",
#             "primarily",
#             "academic",
#             "computer",
#             "software",
#             "prewritten/canned",
#             "electronically",
#             "purposes",
#             "designed"
#           ],
#           "0502": [
#             "educational",
#             "customized",
#             "downloaded",
#             "business-to-customer",
#             "transferred",
#             "non-educational",
#             "primarily",
#             "academic",
#             "computer",
#             "software",
#             "prewritten/canned",
#             "electronically",
#             "purposes",
#             "designed",
#             "something"
#           ],
#           "0503": [
#             "business-to-business",
#             "downloaded",
#             "non-educational",
#             "computer",
#             "software",
#             "prewritten/canned",
#             "electronically"
#           ],
#           "0600": [
#             "via",
#             "'s",
#             "left",
#             "customized",
#             "loaded",
#             "business-to-customer",
#             "customer",
#             "load",
#             "computer",
#             "software",
#             "prewritten/canned",
#             "leave",
#             "media",
#             "delivered",
#             "actual",
#             "physical",
#             "onsite"
#           ]
#         }
#       ],
#       "06": [
#         [
#           "previously",
#           "fee",
#           "renewals",
#           "canned",
#           "license",
#           "software",
#           "periodic",
#           "license-to-use",
#           "purchased"
#         ],
#         {
#           "0000": [
#             "previously",
#             "fee",
#             "renewals",
#             "canned",
#             "license",
#             "software",
#             "periodic",
#             "license-to-use",
#             "purchased"
#           ]
#         }
#       ],
#       "07": [
#         [
#           "cloud/remote",
#           "storage"
#         ],
#         {
#           "0000": [
#             "cloud/remote",
#             "storage"
#           ]
#         }
#       ]
#     }
#   ],
#   "DD": [
#     [
#       "plans",
#       "goods",
#       "digital",
#       "designs",
#       "transferred",
#       "means",
#       "customer",
#       "electronic",
#       "media",
#       "physical"
#     ],
#     {
#       "02": [
#         [
#           "plans",
#           "goods",
#           "digital",
#           "designs",
#           "transferred",
#           "means",
#           "customer",
#           "electronic",
#           "media",
#           "physical"
#         ],
#         {
#           "0000": [
#             "plans",
#             "goods",
#             "digital",
#             "designs",
#             "transferred",
#             "means",
#             "customer",
#             "electronic",
#             "media",
#             "physical"
#           ]
#         }
#       ],
#       "04": [
#         [
#           "other",
#           "documentation",
#           "goods",
#           "digital",
#           "transferred",
#           "means",
#           "customer",
#           "tax",
#           "media",
#           "specific",
#           "identified",
#           "code",
#           "electronic",
#           "physical"
#         ],
#         {
#           "0000": [
#             "other",
#             "documentation",
#             "goods",
#             "digital",
#             "transferred",
#             "means",
#             "customer",
#             "tax",
#             "media",
#             "specific",
#             "identified",
#             "code",
#             "electronic",
#             "physical"
#           ]
#         }
#       ]
#     }
#   ],
#   "DG": [
#     [
#       "goods",
#       "digital",
#       "transferred",
#       "means",
#       "customer",
#       "electronic",
#       "games",
#       "otherwise"
#     ],
#     {
#       "01": [
#         [
#           "goods",
#           "digital",
#           "transferred",
#           "means",
#           "customer",
#           "electronic",
#           "games",
#           "otherwise"
#         ],
#         {
#           "0000": [
#             "goods",
#             "digital",
#             "transferred",
#             "means",
#             "customer",
#             "electronic",
#             "games",
#             "otherwise"
#           ],
#           "0100": [
#             "goods",
#             "digital",
#             "standard",
#             "transferred",
#             "means",
#             "customer",
#             "media",
#             "games",
#             "games-physical",
#             "physical"
#           ],
#           "0200": [
#             "games-streaming",
#             "goods",
#             "digital",
#             "games",
#             "transferred",
#             "means",
#             "customer",
#             "electronic",
#             "download"
#           ],
#           "0201": [
#             "made",
#             "chicago",
#             "transferred",
#             "means",
#             "games",
#             "otherwise",
#             "temporary",
#             "interest",
#             "on-line",
#             "customer",
#             "amusement",
#             "note",
#             "tax",
#             "description",
#             "apply",
#             "transactions",
#             "use",
#             "streaming",
#             "applies",
#             "purposes",
#             "ownership",
#             "participating",
#             "addresses",
#             "see",
#             "additional",
#             "non-possessory",
#             "electronic",
#             "code",
#             "download"
#           ],
#           "0300": [
#             "download",
#             "electronic",
#             "permanent",
#             "games",
#             "ownership"
#           ],
#           "0301": [
#             "streaming",
#             "download",
#             "electronic",
#             "permanent",
#             "games",
#             "less",
#             "ownership"
#           ],
#           "0302": [
#             "made",
#             "addresses",
#             "use",
#             "streaming",
#             "download",
#             "chicago",
#             "amusement",
#             "note",
#             "electronic",
#             "apply",
#             "permanent",
#             "code",
#             "games",
#             "less",
#             "ownership",
#             "tax",
#             "transactions"
#           ]
#         }
#       ],
#       "02": [
#         [
#           "cards",
#           "electronically-delivered",
#           "gift"
#         ],
#         {
#           "0000": [
#             "cards",
#             "electronically-delivered",
#             "gift"
#           ]
#         }
#       ]
#     }
#   ],
#   "DI": [
#     [
#       "digital",
#       "images",
#       "birth",
#       "transferred",
#       "invoices",
#       "etc",
#       "customer",
#       "means",
#       "electronic",
#       "certificates",
#       "otherwise"
#     ],
#     {
#       "01": [
#         [
#           "digital",
#           "images",
#           "birth",
#           "transferred",
#           "invoices",
#           "etc",
#           "customer",
#           "means",
#           "electronic",
#           "certificates",
#           "otherwise"
#         ],
#         {
#           "0000": [
#             "digital",
#             "images",
#             "birth",
#             "transferred",
#             "invoices",
#             "etc",
#             "customer",
#             "means",
#             "electronic",
#             "certificates",
#             "otherwise"
#           ],
#           "0100": [
#             "digital",
#             "standard",
#             "images",
#             "transferred",
#             "images-physical",
#             "customer",
#             "means",
#             "media",
#             "physical"
#           ],
#           "0200": [
#             "images-streaming",
#             "digital",
#             "images",
#             "transferred",
#             "means",
#             "customer",
#             "electronic",
#             "download"
#           ],
#           "0201": [
#             "made",
#             "possessory",
#             "chicago",
#             "transferred",
#             "means",
#             "privilege",
#             "permanent",
#             "delivered",
#             "granted",
#             "subscription",
#             "interest",
#             "digital",
#             "customer",
#             "amusement",
#             "note",
#             "tax",
#             "description",
#             "electronically",
#             "television",
#             "apply",
#             "transactions",
#             "use",
#             "shows",
#             "images",
#             "streaming",
#             "pay-per-view",
#             "purposes",
#             "videos",
#             "movies",
#             "wherein",
#             "title",
#             "addresses",
#             "see",
#             "watching",
#             "additional",
#             "electronic",
#             "code",
#             "download"
#           ]
#         }
#       ]
#     }
#   ],
#   "DL": [
#     [
#       "wills",
#       "documentation",
#       "goods",
#       "digital",
#       "transferred",
#       "means",
#       "etc",
#       "customer",
#       "legal",
#       "media",
#       "contracts",
#       "electronic",
#       "physical"
#     ],
#     {
#       "02": [
#         [
#           "wills",
#           "documentation",
#           "goods",
#           "digital",
#           "transferred",
#           "means",
#           "etc",
#           "customer",
#           "legal",
#           "media",
#           "contracts",
#           "electronic",
#           "physical"
#         ],
#         {
#           "0000": [
#             "wills",
#             "documentation",
#             "goods",
#             "digital",
#             "transferred",
#             "means",
#             "etc",
#             "customer",
#             "legal",
#             "media",
#             "contracts",
#             "electronic",
#             "physical"
#           ]
#         }
#       ]
#     }
#   ],
#   "DM": [
#     [
#       "also",
#       "mean",
#       "transferred",
#       "non-business",
#       "intervals",
#       "regular",
#       "sold",
#       "published",
#       "digital",
#       "ordinary",
#       "usual",
#       "works",
#       "electronically",
#       "files",
#       "magazine",
#       "version",
#       "use",
#       "magazines",
#       "printed",
#       "information",
#       "generally",
#       "identical",
#       "hard-copy",
#       "versions",
#       "sense",
#       "recognized"
#     ],
#     {
#       "01": [
#         [
#           "also",
#           "mean",
#           "transferred",
#           "non-business",
#           "intervals",
#           "regular",
#           "sold",
#           "published",
#           "digital",
#           "ordinary",
#           "usual",
#           "works",
#           "electronically",
#           "files",
#           "magazine",
#           "version",
#           "use",
#           "magazines",
#           "printed",
#           "information",
#           "generally",
#           "identical",
#           "hard-copy",
#           "versions",
#           "sense",
#           "recognized"
#         ],
#         {
#           "0100": [
#             "also",
#             "mean",
#             "transferred",
#             "non-business",
#             "intervals",
#             "regular",
#             "sold",
#             "published",
#             "digital",
#             "ordinary",
#             "usual",
#             "works",
#             "electronically",
#             "files",
#             "magazine",
#             "version",
#             "use",
#             "magazines",
#             "printed",
#             "information",
#             "generally",
#             "identical",
#             "hard-copy",
#             "versions",
#             "sense",
#             "recognized"
#           ]
#         }
#       ],
#       "02": [
#         [
#           "goods",
#           "digital",
#           "related",
#           "sales",
#           "lists",
#           "transferred",
#           "means",
#           "customer",
#           "list",
#           "information",
#           "electronic",
#           "mailing",
#           "otherwise"
#         ],
#         {
#           "0000": [
#             "goods",
#             "digital",
#             "related",
#             "sales",
#             "lists",
#             "transferred",
#             "means",
#             "customer",
#             "list",
#             "information",
#             "electronic",
#             "mailing",
#             "otherwise"
#           ],
#           "0100": [
#             "lists-physical",
#             "goods",
#             "digital",
#             "standard",
#             "transferred",
#             "means",
#             "customer",
#             "list",
#             "media",
#             "mailing",
#             "physical"
#           ],
#           "0200": [
#             "goods",
#             "digital",
#             "transferred",
#             "means",
#             "customer",
#             "electronic",
#             "lists-streaming",
#             "list",
#             "download",
#             "mailing"
#           ]
#         }
#       ],
#       "03": [
#         [
#           "goods",
#           "digital",
#           "transferred",
#           "means",
#           "customer",
#           "electronic",
#           "movies",
#           "otherwise"
#         ],
#         {
#           "0000": [
#             "goods",
#             "digital",
#             "transferred",
#             "means",
#             "customer",
#             "electronic",
#             "movies",
#             "otherwise"
#           ],
#           "0100": [
#             "goods",
#             "digital",
#             "standard",
#             "transferred",
#             "means",
#             "customer",
#             "movies",
#             "media",
#             "movies-physical",
#             "physical"
#           ],
#           "0200": [
#             "movies-streaming",
#             "goods",
#             "digital",
#             "transferred",
#             "means",
#             "customer",
#             "electronic",
#             "movies",
#             "download"
#           ],
#           "0201": [
#             "made",
#             "possessory",
#             "chicago",
#             "transferred",
#             "means",
#             "privilege",
#             "permanent",
#             "delivered",
#             "granted",
#             "subscription",
#             "interest",
#             "customer",
#             "amusement",
#             "note",
#             "tax",
#             "description",
#             "electronically",
#             "television",
#             "apply",
#             "transactions",
#             "use",
#             "shows",
#             "streaming",
#             "pay-per-view",
#             "purposes",
#             "videos",
#             "movies",
#             "wherein",
#             "title",
#             "addresses",
#             "see",
#             "watching",
#             "additional",
#             "electronic",
#             "code",
#             "download"
#           ]
#         }
#       ],
#       "04": [
#         [
#           "goods",
#           "digital",
#           "transferred",
#           "means",
#           "customer",
#           "electronic",
#           "otherwise",
#           "music"
#         ],
#         {
#           "0000": [
#             "goods",
#             "digital",
#             "transferred",
#             "means",
#             "customer",
#             "electronic",
#             "otherwise",
#             "music"
#           ],
#           "0100": [
#             "goods",
#             "digital",
#             "standard",
#             "music-physical",
#             "transferred",
#             "means",
#             "customer",
#             "media",
#             "physical",
#             "music"
#           ],
#           "0200": [
#             "goods",
#             "digital",
#             "transferred",
#             "means",
#             "customer",
#             "electronic",
#             "music-streaming",
#             "download",
#             "music"
#           ],
#           "0201": [
#             "made",
#             "possessory",
#             "chicago",
#             "transferred",
#             "means",
#             "privilege",
#             "permanent",
#             "delivered",
#             "granted",
#             "music",
#             "subscription",
#             "interest",
#             "customer",
#             "amusement",
#             "note",
#             "tax",
#             "description",
#             "electronically",
#             "apply",
#             "transactions",
#             "listening",
#             "use",
#             "streaming",
#             "purposes",
#             "wherein",
#             "title",
#             "addresses",
#             "see",
#             "additional",
#             "electronic",
#             "code",
#             "download"
#           ]
#         }
#       ]
#     }
#   ],
#   "DN": [
#     [
#       "also",
#       "mean",
#       "means",
#       "non-business",
#       "publications",
#       "daily",
#       "intervals",
#       "short",
#       "public",
#       "sold",
#       "edition",
#       "subscription",
#       "interest",
#       "transmitted",
#       "digital",
#       "access",
#       "customer",
#       "periodically",
#       "weekly",
#       "newspapers",
#       "print",
#       "version",
#       "use",
#       "commonly",
#       "newspaper",
#       "printed",
#       "dissemination",
#       "information",
#       "news",
#       "hard-copy",
#       "versions",
#       "\u2013",
#       "general",
#       "content",
#       "distributed",
#       "character",
#       "electronic",
#       "understood",
#       "similar"
#     ],
#     {
#       "01": [
#         [
#           "also",
#           "mean",
#           "means",
#           "non-business",
#           "publications",
#           "daily",
#           "intervals",
#           "short",
#           "public",
#           "sold",
#           "edition",
#           "subscription",
#           "interest",
#           "transmitted",
#           "digital",
#           "access",
#           "customer",
#           "periodically",
#           "weekly",
#           "newspapers",
#           "print",
#           "version",
#           "use",
#           "commonly",
#           "newspaper",
#           "printed",
#           "dissemination",
#           "information",
#           "news",
#           "hard-copy",
#           "versions",
#           "\u2013",
#           "general",
#           "content",
#           "distributed",
#           "character",
#           "electronic",
#           "understood",
#           "similar"
#         ],
#         {
#           "0000": [
#             "also",
#             "mean",
#             "means",
#             "non-business",
#             "publications",
#             "daily",
#             "intervals",
#             "short",
#             "public",
#             "sold",
#             "edition",
#             "subscription",
#             "interest",
#             "transmitted",
#             "digital",
#             "access",
#             "customer",
#             "periodically",
#             "weekly",
#             "newspapers",
#             "print",
#             "version",
#             "use",
#             "commonly",
#             "newspaper",
#             "printed",
#             "dissemination",
#             "information",
#             "news",
#             "hard-copy",
#             "versions",
#             "\u2013",
#             "general",
#             "content",
#             "distributed",
#             "character",
#             "electronic",
#             "understood",
#             "similar"
#           ]
#         }
#       ]
#     }
#   ],
#   "DO": [
#     [
#       "other",
#       "goods",
#       "digital",
#       "specifically",
#       "sales",
#       "transferred",
#       "means",
#       "customer",
#       "tax",
#       "media",
#       "another",
#       "identified",
#       "code",
#       "electronic",
#       "physical"
#     ],
#     {
#       "01": [
#         [
#           "other",
#           "goods",
#           "digital",
#           "specifically",
#           "sales",
#           "transferred",
#           "means",
#           "customer",
#           "tax",
#           "media",
#           "another",
#           "identified",
#           "code",
#           "electronic",
#           "physical"
#         ],
#         {
#           "0000": [
#             "other",
#             "goods",
#             "digital",
#             "specifically",
#             "sales",
#             "transferred",
#             "means",
#             "customer",
#             "tax",
#             "media",
#             "another",
#             "identified",
#             "code",
#             "electronic",
#             "physical"
#           ]
#         }
#       ]
#     }
#   ],
#   "DP": [
#     [
#       "goods",
#       "digital",
#       "transferred",
#       "means",
#       "customer",
#       "electronic",
#       "photographs",
#       "otherwise"
#     ],
#     {
#       "01": [
#         [
#           "goods",
#           "digital",
#           "transferred",
#           "means",
#           "customer",
#           "electronic",
#           "photographs",
#           "otherwise"
#         ],
#         {
#           "0000": [
#             "goods",
#             "digital",
#             "transferred",
#             "means",
#             "customer",
#             "electronic",
#             "photographs",
#             "otherwise"
#           ],
#           "0100": [
#             "goods",
#             "digital",
#             "standard",
#             "transferred",
#             "means",
#             "customer",
#             "media",
#             "physical",
#             "photographs",
#             "photographs-physical"
#           ],
#           "0200": [
#             "photographs-streaming",
#             "transferred",
#             "means",
#             "delivery",
#             "photographs",
#             "may",
#             "jurisdictions",
#             "goods",
#             "digital",
#             "customer",
#             "note",
#             "invoice",
#             "``",
#             "exemption",
#             "qualify",
#             "electronic",
#             "stated",
#             "download",
#             "required",
#             "''"
#           ],
#           "0201": [
#             "made",
#             "possessory",
#             "chicago",
#             "transferred",
#             "means",
#             "privilege",
#             "permanent",
#             "photographs",
#             "delivered",
#             "granted",
#             "subscription",
#             "interest",
#             "customer",
#             "amusement",
#             "note",
#             "tax",
#             "description",
#             "electronically",
#             "television",
#             "apply",
#             "transactions",
#             "use",
#             "shows",
#             "streaming",
#             "pay-per-view",
#             "purposes",
#             "videos",
#             "movies",
#             "wherein",
#             "title",
#             "addresses",
#             "see",
#             "watching",
#             "additional",
#             "electronic",
#             "code",
#             "download"
#           ]
#         }
#       ]
#     }
#   ],
#   "DV": [
#     [
#       "goods",
#       "digital",
#       "transferred",
#       "means",
#       "customer",
#       "videos",
#       "electronic",
#       "otherwise"
#     ],
#     {
#       "01": [
#         [
#           "goods",
#           "digital",
#           "transferred",
#           "means",
#           "customer",
#           "videos",
#           "electronic",
#           "otherwise"
#         ],
#         {
#           "0000": [
#             "goods",
#             "digital",
#             "transferred",
#             "means",
#             "customer",
#             "videos",
#             "electronic",
#             "otherwise"
#           ],
#           "0100": [
#             "goods",
#             "digital",
#             "standard",
#             "transferred",
#             "means",
#             "customer",
#             "videos-physical",
#             "videos",
#             "media",
#             "physical"
#           ],
#           "0200": [
#             "goods",
#             "digital",
#             "transferred",
#             "means",
#             "customer",
#             "videos",
#             "electronic",
#             "download",
#             "videos-streaming"
#           ],
#           "0201": [
#             "made",
#             "possessory",
#             "chicago",
#             "transferred",
#             "means",
#             "privilege",
#             "permanent",
#             "delivered",
#             "granted",
#             "subscription",
#             "interest",
#             "customer",
#             "amusement",
#             "note",
#             "tax",
#             "description",
#             "electronically",
#             "television",
#             "apply",
#             "transactions",
#             "use",
#             "shows",
#             "streaming",
#             "pay-per-view",
#             "videos",
#             "purposes",
#             "movies",
#             "wherein",
#             "title",
#             "addresses",
#             "see",
#             "watching",
#             "additional",
#             "electronic",
#             "code",
#             "download"
#           ],
#           "7194": [
#             "type",
#             "video",
#             "please",
#             "delivery",
#             "depending",
#             "facilities",
#             "may",
#             "protocol",
#             "cable",
#             "on-demand",
#             "include",
#             "note",
#             "television",
#             "services",
#             "streamed",
#             "cable-related",
#             "programming",
#             "streaming",
#             "regard",
#             "service",
#             "state",
#             "internet",
#             "wireline",
#             "subscribers",
#             "taxes",
#             "provided",
#             "wireless",
#             "prepaid",
#             "without",
#             "satellite",
#             "subject",
#             "code",
#             "technology",
#             "broadcasts"
#           ]
#         }
#       ],
#       "02": [
#         [
#           "visual",
#           "audio",
#           "digital",
#           "works"
#         ],
#         {
#           "1000": [
#             "visual",
#             "audio",
#             "digital",
#             "works"
#           ],
#           "1007": [
#             "visual",
#             "rights",
#             "audio",
#             "digital",
#             "use",
#             "user",
#             "end",
#             "works",
#             "permanent",
#             "sold"
#           ],
#           "1008": [
#             "visual",
#             "audio",
#             "digital",
#             "use",
#             "works",
#             "permanent",
#             "less",
#             "rights"
#           ],
#           "1009": [
#             "visual",
#             "audio",
#             "digital",
#             "payments",
#             "works",
#             "continued",
#             "conditioned",
#             "rights"
#           ],
#           "1010": [
#             "made",
#             "visual",
#             "avatax",
#             "possessory",
#             "chicago",
#             "transferred",
#             "means",
#             "permanent",
#             "privilege",
#             "delivered",
#             "granted",
#             "subscription",
#             "interest",
#             "audio",
#             "digital",
#             "customer",
#             "amusement",
#             "note",
#             "tax",
#             "works",
#             "electronically",
#             "television",
#             "system",
#             "apply",
#             "transactions",
#             "use",
#             "shows",
#             "streaming",
#             "pay-per-view",
#             "videos",
#             "purposes",
#             "information",
#             "movies",
#             "wherein",
#             "title",
#             "addresses",
#             "see",
#             "watching",
#             "additional",
#             "electronic",
#             "code",
#             "less",
#             "rights"
#           ],
#           "9398": [
#             "visual",
#             "users",
#             "audio",
#             "digital",
#             "user",
#             "end",
#             "works",
#             "sold"
#           ]
#         }
#       ]
#     }
#   ],
#   "FR": [
#     [
#       "freight",
#       "special",
#       "delivery",
#       "sold",
#       "charges",
#       "goods",
#       "customer",
#       "applicable",
#       "identified",
#       "seller",
#       "paid",
#       "handling",
#       "product",
#       "company",
#       "separately",
#       "shipping",
#       "represent",
#       "preparing",
#       "cost",
#       "transportation"
#     ],
#     {
#       "": [
#         [
#           "takes",
#           "fob",
#           "transferred",
#           "delivery",
#           "possession",
#           "backward",
#           "charges",
#           "goods",
#           "common",
#           "compatibility",
#           "time",
#           "customer",
#           "destination",
#           "seller",
#           "paid",
#           "product",
#           "title",
#           "shipping",
#           "third-party",
#           "carrier"
#         ],
#         {
#           "": [
#             "takes",
#             "fob",
#             "transferred",
#             "delivery",
#             "possession",
#             "backward",
#             "charges",
#             "goods",
#             "common",
#             "compatibility",
#             "time",
#             "customer",
#             "destination",
#             "seller",
#             "paid",
#             "product",
#             "title",
#             "shipping",
#             "third-party",
#             "carrier"
#           ]
#         }
#       ],
#       "00": [
#         [
#           "freight",
#           "special",
#           "delivery",
#           "sold",
#           "charges",
#           "goods",
#           "customer",
#           "applicable",
#           "identified",
#           "seller",
#           "paid",
#           "handling",
#           "product",
#           "company",
#           "separately",
#           "shipping",
#           "represent",
#           "preparing",
#           "cost",
#           "transportation"
#         ],
#         {
#           "0000": [
#             "freight",
#             "special",
#             "delivery",
#             "sold",
#             "charges",
#             "goods",
#             "customer",
#             "applicable",
#             "identified",
#             "seller",
#             "paid",
#             "handling",
#             "product",
#             "company",
#             "separately",
#             "shipping",
#             "represent",
#             "preparing",
#             "cost",
#             "transportation"
#           ]
#         }
#       ],
#       "01": [
#         [
#           "party",
#           "charges",
#           "seller",
#           "products",
#           "rather",
#           "third",
#           "sold",
#           "imposed",
#           "service",
#           "product",
#           "delivery",
#           "company",
#           "using",
#           "transportation",
#           "vehicle"
#         ],
#         {
#           "0000": [
#             "party",
#             "charges",
#             "seller",
#             "products",
#             "rather",
#             "third",
#             "sold",
#             "imposed",
#             "service",
#             "product",
#             "delivery",
#             "company",
#             "using",
#             "transportation",
#             "vehicle"
#           ],
#           "0100": [
#             "takes",
#             "passage",
#             "fob",
#             "delivery",
#             "possession",
#             "sold",
#             "charges",
#             "customer",
#             "using",
#             "destination",
#             "vehicle",
#             "seller",
#             "take",
#             "imposed",
#             "service",
#             "product",
#             "transfer",
#             "company",
#             "title",
# ...
#       "seeking",
#       "rental",
#       "costs",
#       "car",
#       "air",
#       "implementation",
#       "reimbursed",
#       "travel"
#     ],
#     {
#       "01": [
#         [
#           "prewritten",
#           "hotel",
#           "software",
#           "charges",
#           "expenses",
#           "related",
#           "etc",
#           "services",
#           "associated",
#           "-associated",
#           "seller",
#           "installation",
#           "seeking",
#           "rental",
#           "costs",
#           "car",
#           "air",
#           "implementation",
#           "reimbursed",
#           "travel"
#         ],
#         {
#           "0100": [
#             "prewritten",
#             "hotel",
#             "software",
#             "charges",
#             "expenses",
#             "related",
#             "etc",
#             "services",
#             "associated",
#             "-associated",
#             "seller",
#             "installation",
#             "seeking",
#             "rental",
#             "costs",
#             "car",
#             "air",
#             "implementation",
#             "reimbursed",
#             "travel"
#           ],
#           "0300": [
#             "property",
#             "tpp",
#             "hotel",
#             "tangible",
#             "and/or",
#             "expenses",
#             "charges",
#             "related",
#             "etc",
#             "services",
#             "associated",
#             "personal",
#             "seller",
#             "installation",
#             "seeking",
#             "rental",
#             "car",
#             "air",
#             "repair",
#             "reimbursed",
#             "travel"
#           ],
#           "0400": [
#             "personnel",
#             "rendered",
#             "professional",
#             "hotel",
#             "medical",
#             "expenses",
#             "charges",
#             "related",
#             "etc",
#             "services",
#             "associated",
#             "seller",
#             "rental",
#             "car",
#             "air",
#             "lawyers",
#             "accountants",
#             "reimbursed",
#             "travel"
#           ],
#           "0600": [
#             "paralegals",
#             "expenses",
#             "products",
#             "charges",
#             "related",
#             "serving",
#             "rendered",
#             "seller",
#             "process",
#             "lawyers",
#             "service",
#             "product",
#             "etc",
#             "legal",
#             "services",
#             "associated",
#             "reimbursed"
#           ]
#         }
#       ]
#     }
#   ],
#   "P0": [
#     [
#       "made",
#       "limit",
#       "property",
#       "number",
#       "deemed",
#       "user",
#       "consequently",
#       "tpp",
#       "taxability",
#       "nature",
#       "tangible",
#       "and/or",
#       "used",
#       "taxable",
#       "etc",
#       "non-taxable",
#       "local",
#       "statutes",
#       "tax",
#       "applicable",
#       "codes",
#       "system",
#       "associated",
#       "specific",
#       "personal",
#       "use",
#       "land",
#       "specifically",
#       "individual",
#       "buildings",
#       "unless",
#       "could",
#       "available",
#       "known",
#       "state",
#       "additionally",
#       "generally",
#       "products",
#       "items",
#       "want",
#       "default",
#       "real",
#       "code",
#       "presumption"
#     ],
#     {
#       "00": [
#         [
#           "made",
#           "limit",
#           "property",
#           "number",
#           "deemed",
#           "user",
#           "consequently",
#           "tpp",
#           "taxability",
#           "nature",
#           "tangible",
#           "and/or",
#           "used",
#           "taxable",
#           "etc",
#           "non-taxable",
#           "local",
#           "statutes",
#           "tax",
#           "applicable",
#           "codes",
#           "system",
#           "associated",
#           "specific",
#           "personal",
#           "use",
#           "land",
#           "specifically",
#           "individual",
#           "buildings",
#           "unless",
#           "could",
#           "available",
#           "known",
#           "state",
#           "additionally",
#           "generally",
#           "products",
#           "items",
#           "want",
#           "default",
#           "real",
#           "code",
#           "presumption"
#         ],
#         {
#           "0000": [
#             "made",
#             "limit",
#             "property",
#             "number",
#             "deemed",
#             "user",
#             "consequently",
#             "tpp",
#             "taxability",
#             "nature",
#             "tangible",
#             "and/or",
#             "used",
#             "taxable",
#             "etc",
#             "non-taxable",
#             "local",
#             "statutes",
#             "tax",
#             "applicable",
#             "codes",
#             "system",
#             "associated",
#             "specific",
#             "personal",
#             "use",
#             "land",
#             "specifically",
#             "individual",
#             "buildings",
#             "unless",
#             "could",
#             "available",
#             "known",
#             "state",
#             "additionally",
#             "generally",
#             "products",
#             "items",
#             "want",
#             "default",
#             "real",
#             "code",
#             "presumption"
#           ],
#           "000H": [
#             "credit",
#             "ensure",
#             "proper",
#             "entry",
#             "calculation",
#             "amount",
#             "tpp",
#             "tax",
#             "negative",
#             "hostess",
#             "requires",
#             "purchased",
#             "credits"
#           ],
#           "100H": [
#             "taxable",
#             "entirely",
#             "tpp",
#             "credits",
#             "hostess",
#             "purchased"
#           ]
#         }
#       ]
#     }
#   ],
#   "P9": [
#     [
#       "unmapped",
#       "tpp",
#       "taxability",
#       "taxing",
#       "temporary",
#       "map",
#       "jurisdictions",
#       "taxable",
#       "used",
#       "tax",
#       "identified",
#       "system",
#       "specific",
#       "sku",
#       "known",
#       "product",
#       "purposes",
#       "this",
#       "products",
#       "default",
#       "code"
#     ],
#     {
#       "99": [
#         [
#           "unmapped",
#           "tpp",
#           "taxability",
#           "taxing",
#           "temporary",
#           "map",
#           "jurisdictions",
#           "taxable",
#           "used",
#           "tax",
#           "identified",
#           "system",
#           "specific",
#           "sku",
#           "known",
#           "product",
#           "purposes",
#           "this",
#           "products",
#           "default",
#           "code"
#         ],
#         {
#           "9999": [
#             "unmapped",
#             "tpp",
#             "taxability",
#             "taxing",
#             "temporary",
#             "map",
#             "jurisdictions",
#             "taxable",
#             "used",
#             "tax",
#             "identified",
#             "system",
#             "specific",
#             "sku",
#             "known",
#             "product",
#             "purposes",
#             "this",
#             "products",
#             "default",
#             "code"
#           ]
#         }
#       ]
#     }
#   ],
#   "PA": [
#     [
#       "agricultural"
#     ],
#     {
#       "02": [
#         [
#           "agricultural"
#         ],
#         {
#           "0000": [
#             "agricultural"
#           ],
#           "0003": [
#             "food",
#             "root",
#             "plants",
#             "plant",
#             "fertilizer",
#             "tone",
#             "producing"
#           ],
#           "0100": [
#             "equipment",
#             "agricultural-commercial",
#             "use-machinery"
#           ],
#           "0111": [
#             "annual",
#             "food",
#             "use",
#             "plants",
#             "producing",
#             "agricultural-commercial"
#           ],
#           "0113": [
#             "food",
#             "<",
#             "use",
#             "producing",
#             "agricultural-commercial",
#             "lbs",
#             "25",
#             "seeds"
#           ],
#           "0120": [
#             "includes",
#             "thermometers",
#             "products",
#             "hanging",
#             "use",
#             "sensors",
#             "agricultural",
#             "etc",
#             "scales",
#             "equipment",
#             "meters",
#             "monitoring",
#             "weather",
#             "livestock-commercial",
#             "testing",
#             "devices"
#           ],
#           "0121": [
#             "includes",
#             "solutions",
#             "products",
#             "use",
#             "foamers",
#             "systems",
#             "water",
#             "filtration",
#             "cleaning",
#             "agricultural",
#             "supplies",
#             "foggers",
#             "etc",
#             "line",
#             "equipment",
#             "cleaners",
#             "livestock-commercial",
#             "sprayers"
#           ],
#           "0122": [
#             "includes",
#             "electric",
#             "buckets",
#             "&",
#             "chutes",
#             "agricultural",
#             "etc",
#             "livestock",
#             "livestock-commercial",
#             "use",
#             "cooling",
#             "calf",
#             "products",
#             "headgates",
#             "waterers",
#             "feeders",
#             "prods",
#             "sorting",
#             "equipment",
#             "scales"
#           ],
#           "0123": [
#             "use",
#             "vaccine",
#             "agricultural",
#             "equipment",
#             "livestock-commercial"
#           ],
#           "0225": [
#             "includes",
#             "blowers",
#             "combs",
#             "dryers",
#             "show",
#             "fans",
#             "&",
#             "agricultural",
#             "sticks",
#             "livestock",
#             "livestock-commercial",
#             "use",
#             "blades",
#             "hair",
#             "halters",
#             "care",
#             "grooming",
#             "restraints",
#             "brushes",
#             "products",
#             "clippers",
#             "supplies",
#             "general"
#           ],
#           "0226": [
#             "applied",
#             "includes",
#             "products",
#             "use",
#             "supplies",
#             "agricultural",
#             "livestock",
#             "livestock-commercial",
#             "disinfectants",
#             "hygiene"
#           ],
#           "0227": [
#             "includes",
#             "animal",
#             "use",
#             "used",
#             "production",
#             "herbicides",
#             "agricultural",
#             "insecticides",
#             "pesticides",
#             "livestock",
#             "livestock-commercial"
#           ],
#           "0228": [
#             "includes",
#             "products",
#             "use",
#             "agricultural",
#             "tags",
#             "identification",
#             "id",
#             "livestock",
#             "brands",
#             "paint",
#             "tattoo",
#             "livestock-commercial"
#           ],
#           "0229": [
#             "includes",
#             "food",
#             "use",
#             "animals",
#             "agricultural",
#             "feed",
#             "livestock",
#             "livestock-commercial",
#             "farm"
#           ],
#           "0230": [
#             "use",
#             "supplies",
#             "agricultural",
#             "safety",
#             "livestock-commercial"
#           ],
#           "0231": [
#             "use",
#             "litter",
#             "agricultural",
#             "livestock-commercial"
#           ],
#           "0300": [
#             "use",
#             "agricultural",
#             "medicine",
#             "livestock-commercial"
#           ],
#           "0301": [
#             "includes",
#             "use",
#             "electrolytes",
#             "non-prescribed",
#             "additives",
#             "counter",
#             "agricultural",
#             "medicines",
#             "medicine",
#             "feed",
#             "supplements",
#             "livestock-commercial",
#             "probiotics",
#             "vitamins"
#           ],
#           "0302": [
#             "prescription",
#             "includes",
#             "inflammation",
#             "use",
#             "water",
#             "additives",
#             "antibiotics",
#             "agricultural",
#             "medicines",
#             "medicine",
#             "feed",
#             "pain",
#             "reproductive",
#             "&",
#             "antibiotic",
#             "livestock-commercial",
#             "dewormers"
#           ],
#           "0303": [
#             "includes",
#             "water",
#             "additives",
#             "antibiotics",
#             "&",
#             "sold",
#             "prescription",
#             "pain",
#             "agricultural",
#             "medicines",
#             "reproductive",
#             "antibiotic",
#             "livestock-commercial",
#             "veterinarians",
#             "use",
#             "feed",
#             "dewormers",
#             "inflammation",
#             "medicine"
#           ],
#           "0304": [
#             "veterinarians",
#             "includes",
#             "use",
#             "swine",
#             "cattle",
#             "poultry",
#             "agricultural",
#             "dairy",
#             "livestock",
#             "livestock-commercial",
#             "vaccines",
#             "sold"
#           ],
#           "0400": [
#             "use",
#             "supplies",
#             "agricultural",
#             "livestock-commercial",
#             "medical"
#           ],
#           "0401": [
#             "includes",
#             "products",
#             "use",
#             "effectiveness",
#             "vaccine",
#             "agricultural",
#             "help",
#             "delivery",
#             "livestock",
#             "livestock-commercial",
#             "stabilizers"
#           ],
#           "0402": [
#             "syringes",
#             "includes",
#             "use",
#             "related",
#             "vaccinators",
#             "kits",
#             "surgical",
#             "accessories",
#             "needles",
#             "agricultural",
#             "aspiration",
#             "equipment",
#             "&",
#             "livestock-commercial",
#             "injection"
#           ],
#           "0659": [
#             "food",
#             "vegetable",
#             "herb",
#             "producing",
#             "fruit",
#             "seeds"
#           ],
#           "0661": [
#             "vegetable",
#             "fruit",
#             "potatoes",
#             "onions",
#             "bulbs"
#           ],
#           "0662": [
#             "includes",
#             "woody",
#             "food",
#             "raspberry",
#             "pear",
#             "ornamental",
#             "plants",
#             "blueberry",
#             "producing",
#             "apple",
#             "trees",
#             "bush",
#             "vines"
#           ],
#           "0664": [
#             "food",
#             "plants",
#             "producing",
#             "insecticides",
#             "fungicides"
#           ],
#           "0665": [
#             "flower",
#             "excludes",
#             "bulbs",
#             "seeds"
#           ],
#           "0668": [
#             "herbicide",
#             "w/",
#             "plants",
#             "fertilizer",
#             "non-food",
#             "fertilizes",
#             "weeds",
#             "insecticide",
#             "producing",
#             "primarily",
#             "kills",
#             "dual-purpose"
#           ],
#           "0738": [
#             "food",
#             "animals",
#             "wild",
#             "farm",
#             "game"
#           ],
#           "1078": [
#             "food",
#             "vegetable",
#             "plants",
#             "herb",
#             "producing",
#             "fruit"
#           ],
#           "8802": [
#             "flowers",
#             "cut"
#           ]
#         }
#       ]
#     }
#   ]
# }

# %%
tc_table_lvl_1 = {}
tc_table_lvl_2 = {}
tc_table_lvl_3 = {}

new_col_name = 'tax_parsed'

for index, tax_code in enumerate(df_xlsx['AvaTax System Tax Code'], 2):
    # if tax_code = NaN
    if isinstance(tax_code, float):
        prefix = df_xlsx["AvaTax System Tax Code"].loc[index + 1]
        level_1 = prefix[0:2]
        level_2 = prefix[2:4]
        level_3 = "0000"
        df_xlsx["AvaTax System Tax Code"].loc[index] = prefix[0:4]+"0000"
    else:
        level_1 = tax_code[0:2]
        level_2 = tax_code[2:4]
        level_3 = tax_code[4:8]


    if level_1 not in tc_table_lvl_1:
        tc_table_lvl_1[level_1] = df_xlsx[new_col_name].loc[index]

    if level_1 + level_2 not in tc_table_lvl_2:
        tc_table_lvl_2[level_1+level_2] = df_xlsx[new_col_name].loc[index]

    if level_1 + level_2 + level_3 not in tc_table_lvl_3:
        tc_table_lvl_3[level_1+level_2+level_3] = df_xlsx[new_col_name].loc[index]

print(json.dumps(tc_table_lvl_1, sort_keys=True, indent=2))
print(json.dumps(tc_table_lvl_2, sort_keys=True, indent=2))
print(json.dumps(tc_table_lvl_3, sort_keys=True, indent=2))
# Out:
# {
#   "D0": [
#     "transferred",
#     "computer",
#     "software",
#     "photographs",
#     "otherwise",
#     "music",
#     "sold",
#     "goods",
#     "digital",
#     "viewed",
#     "include",
#     "would",
#     "electronically",
#     "files",
#     "pdfs",
#     "artwork",
#     "movies",
#     "generally",
#     "websites",
#     "e-books",
#     "downloadable",
#     "items",
#     "examples",
#     "zip"
#   ],
#   "D9": [
#     "limited",
#     "unmapped",
#     "cases",
#     "mapped",
#     "temporary",
#     "goods",
#     "digital",
#     "taxable",
#     "applicable",
#     "tax",
#     "system",
#     "base",
#     "specific",
#     "using",
#     "sku",
#     "use",
#     "accurately",
#     "assigned",
#     "unless",
#     "impose",
#     "adequately",
#     "exemption",
#     "purpose",
#     "reviewed",
#     "good",
#     "getting",
#     "entity",
#     "default",
#     "code"
#   ],
#   "DA": [
#     "property",
#     "designs",
#     "transferred",
#     "means",
#     "tangible",
#     "advertising",
#     "goods",
#     "digital",
#     "etc",
#     "customer",
#     "services",
#     "associated",
#     "personal",
#     "artwork",
#     "media",
#     "photos",
#     "physical",
#     "material",
#     "electronic"
#   ],
#   "DB": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "blueprints",
#     "electronic",
#     "media",
#     "physical"
#   ],
#   "DC": [
#     "user",
#     "transferred",
#     "non-business",
#     "load",
#     "computer",
#     "software",
#     "sold",
#     "business-to-business",
#     "forms",
#     "end",
#     "operation",
#     "customer",
#     "electronically",
#     "various",
#     "``",
#     "either",
#     "media",
#     "leave",
#     "physical",
#     "business",
#     "''"
#   ],
#   "DD": [
#     "plans",
#     "goods",
#     "digital",
#     "designs",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "media",
#     "physical"
#   ],
#   "DG": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "games",
#     "otherwise"
#   ],
#   "DI": [
#     "digital",
#     "images",
#     "birth",
#     "transferred",
#     "invoices",
#     "etc",
#     "customer",
#     "means",
#     "electronic",
#     "certificates",
#     "otherwise"
#   ],
#   "DL": [
#     "wills",
#     "documentation",
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "etc",
#     "customer",
#     "legal",
#     "media",
#     "contracts",
#     "electronic",
#     "physical"
#   ],
#   "DM": [
#     "also",
#     "mean",
#     "transferred",
#     "non-business",
#     "intervals",
#     "regular",
#     "sold",
#     "published",
#     "digital",
#     "ordinary",
#     "usual",
#     "works",
#     "electronically",
#     "files",
#     "magazine",
#     "version",
#     "use",
#     "magazines",
#     "printed",
#     "information",
#     "generally",
#     "identical",
#     "hard-copy",
#     "versions",
#     "sense",
#     "recognized"
#   ],
#   "DN": [
#     "also",
#     "mean",
#     "means",
#     "non-business",
#     "publications",
#     "daily",
#     "intervals",
#     "short",
#     "public",
#     "sold",
#     "edition",
#     "subscription",
#     "interest",
#     "transmitted",
#     "digital",
#     "access",
#     "customer",
#     "periodically",
#     "weekly",
#     "newspapers",
#     "print",
#     "version",
#     "use",
#     "commonly",
#     "newspaper",
#     "printed",
#     "dissemination",
#     "information",
#     "news",
#     "hard-copy",
#     "versions",
#     "\u2013",
#     "general",
#     "content",
#     "distributed",
#     "character",
#     "electronic",
#     "understood",
#     "similar"
#   ],
#   "DO": [
#     "other",
#     "goods",
#     "digital",
#     "specifically",
#     "sales",
#     "transferred",
#     "means",
#     "customer",
#     "tax",
#     "media",
#     "another",
#     "identified",
#     "code",
#     "electronic",
#     "physical"
#   ],
#   "DP": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "photographs",
#     "otherwise"
#   ],
#   "DV": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "videos",
#     "electronic",
#     "otherwise"
#   ],
#   "FR": [
#     "freight",
#     "special",
#     "delivery",
#     "sold",
#     "charges",
#     "goods",
#     "customer",
#     "applicable",
#     "identified",
#     "seller",
#     "paid",
#     "handling",
#     "product",
#     "company",
#     "separately",
#     "shipping",
#     "represent",
#     "preparing",
#     "cost",
#     "transportation"
#   ],
#   "O0": [
#     "other",
#     "charges",
#     "sale",
#     "personal",
#     "viewed",
#     "property",
#     "performance",
#     "either",
#     "service",
#     "types",
#     "tangible",
#     "normally",
#     "miscellaneous"
#   ],
#   "O9": [
#     "unmapped",
#     "taxability",
#     "know",
#     "taxing",
#     "temporary",
#     "map",
#     "jurisdictions",
#     "taxable",
#     "used",
#     "tax",
#     "identified",
#     "system",
#     "specific",
#     "non-products",
#     "sku",
#     "service",
#     "product",
#     "purposes",
#     "this",
#     "states",
#     "default",
#     "code"
#   ],
#   "OA": [
#     "parks",
#     "concerts",
#     "admission",
#     "cultural",
#     "may",
#     "sales",
#     "fees",
#     "amusement",
#     "note",
#     "events",
#     "tax",
#     "apply",
#     "entertainment",
#     "admissions",
#     "series",
#     "considers",
#     "excludes",
#     "sporting",
#     "code"
#   ],
#   "OC": [
#     "party",
#     "coupons",
#     "third"
#   ],
#   "OD": [
#     "vendor",
#     "payment",
#     "early",
#     "cash",
#     "opposed",
#     "discounts"
#   ],
#   "OE": [
#     "similar",
#     "exchange/trade-ins",
#     "items"
#   ],
#   "OF": [
#     "cancellation",
#     "fees"
#   ],
#   "OH": [
#     "separately",
#     "charges",
#     "handling",
#     "shipping",
#     "identified"
#   ],
#   "OL": [
#     "property",
#     "commercial",
#     "use",
#     "boat",
#     "access",
#     "concessionaire",
#     "estate",
#     "license",
#     "mailbox",
#     "real",
#     "kitchen",
#     "facilities",
#     "restricted",
#     "launch"
#   ],
#   "OM": [
#     "made",
#     "donation",
#     "event",
#     "organization",
#     "place",
#     "charitable",
#     "amusement",
#     "admission",
#     "sporting",
#     "exchange",
#     "etc",
#     "voluntarily",
#     "monetary"
#   ],
#   "ON": [
#     "deposits",
#     "non-refundable"
#   ],
#   "OO": [
#     "occasional",
#     "sales"
#   ],
#   "OR": [
#     "fees",
#     "restocking"
#   ],
#   "OT": [
#     "prewritten",
#     "hotel",
#     "software",
#     "charges",
#     "expenses",
#     "related",
#     "etc",
#     "services",
#     "associated",
#     "-associated",
#     "seller",
#     "installation",
#     "seeking",
#     "rental",
#     "costs",
#     "car",
#     "air",
#     "implementation",
#     "reimbursed",
#     "travel"
#   ],
#   "P0": [
#     "made",
#     "limit",
#     "property",
#     "number",
#     "deemed",
#     "user",
#     "consequently",
#     "tpp",
#     "taxability",
#     "nature",
#     "tangible",
#     "and/or",
#     "used",
#     "taxable",
#     "etc",
#     "non-taxable",
#     "local",
#     "statutes",
#     "tax",
#     "applicable",
#     "codes",
#     "system",
#     "associated",
#     "specific",
#     "personal",
#     "use",
#     "land",
#     "specifically",
#     "individual",
#     "buildings",
#     "unless",
#     "could",
#     "available",
#     "known",
#     "state",
#     "additionally",
#     "generally",
#     "products",
#     "items",
#     "want",
#     "default",
#     "real",
#     "code",
#     "presumption"
#   ],
#   "P9": [
#     "unmapped",
#     "tpp",
#     "taxability",
#     "taxing",
#     "temporary",
#     "map",
#     "jurisdictions",
#     "taxable",
#     "used",
#     "tax",
#     "identified",
#     "system",
#     "specific",
#     "sku",
#     "known",
#     "product",
#     "purposes",
#     "this",
#     "products",
#     "default",
#     "code"
#   ],
#   "PA": [
#     "agricultural"
#   ]
# }
# {
#   "D000": [
#     "transferred",
#     "computer",
#     "software",
#     "photographs",
#     "otherwise",
#     "music",
#     "sold",
#     "goods",
#     "digital",
#     "viewed",
#     "include",
#     "would",
#     "electronically",
#     "files",
#     "pdfs",
#     "artwork",
#     "movies",
#     "generally",
#     "websites",
#     "e-books",
#     "downloadable",
#     "items",
#     "examples",
#     "zip"
#   ],
#   "D999": [
#     "limited",
#     "unmapped",
#     "cases",
#     "mapped",
#     "temporary",
#     "goods",
#     "digital",
#     "taxable",
#     "applicable",
#     "tax",
#     "system",
#     "base",
#     "specific",
#     "using",
#     "sku",
#     "use",
#     "accurately",
#     "assigned",
#     "unless",
#     "impose",
#     "adequately",
#     "exemption",
#     "purpose",
#     "reviewed",
#     "good",
#     "getting",
#     "entity",
#     "default",
#     "code"
#   ],
#   "DA01": [
#     "property",
#     "designs",
#     "transferred",
#     "means",
#     "tangible",
#     "advertising",
#     "goods",
#     "digital",
#     "etc",
#     "customer",
#     "services",
#     "associated",
#     "personal",
#     "artwork",
#     "media",
#     "photos",
#     "physical",
#     "material",
#     "electronic"
#   ],
#   "DA03": [
#     "goods",
#     "digital",
#     "transferred",
#     "canned",
#     "customer",
#     "artwork",
#     "art",
#     "means",
#     "electronic",
#     "media",
#     "physical"
#   ],
#   "DA04": [
#     "audio",
#     "goods",
#     "digital",
#     "spoken",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "media",
#     "word",
#     "physical",
#     "music"
#   ],
#   "DA05": [
#     "audio",
#     "digital",
#     "works"
#   ],
#   "DB01": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "blueprints",
#     "electronic",
#     "media",
#     "physical"
#   ],
#   "DB02": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "media",
#     "physical",
#     "books"
#   ],
#   "DB03": [
#     "digital",
#     "books"
#   ],
#   "DC01": [
#     "user",
#     "transferred",
#     "non-business",
#     "load",
#     "computer",
#     "software",
#     "sold",
#     "business-to-business",
#     "forms",
#     "end",
#     "operation",
#     "customer",
#     "electronically",
#     "various",
#     "``",
#     "either",
#     "media",
#     "leave",
#     "physical",
#     "business",
#     "''"
#   ],
#   "DC02": [
#     "user",
#     "transferred",
#     "non-business",
#     "load",
#     "computer",
#     "software",
#     "sold",
#     "forms",
#     "business-to-customer",
#     "end",
#     "customer",
#     "electronically",
#     "various",
#     "``",
#     "either",
#     "media",
#     "leave",
#     "physical",
#     "business",
#     "''"
#   ],
#   "DC06": [
#     "previously",
#     "fee",
#     "renewals",
#     "canned",
#     "license",
#     "software",
#     "periodic",
#     "license-to-use",
#     "purchased"
#   ],
#   "DC07": [
#     "cloud/remote",
#     "storage"
#   ],
#   "DD02": [
#     "plans",
#     "goods",
#     "digital",
#     "designs",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "media",
#     "physical"
#   ],
#   "DD04": [
#     "other",
#     "documentation",
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "tax",
#     "media",
#     "specific",
#     "identified",
#     "code",
#     "electronic",
#     "physical"
#   ],
#   "DG01": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "games",
#     "otherwise"
#   ],
#   "DG02": [
#     "cards",
#     "electronically-delivered",
#     "gift"
#   ],
#   "DI01": [
#     "digital",
#     "images",
#     "birth",
#     "transferred",
#     "invoices",
#     "etc",
#     "customer",
#     "means",
#     "electronic",
#     "certificates",
#     "otherwise"
#   ],
#   "DL02": [
#     "wills",
#     "documentation",
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "etc",
#     "customer",
#     "legal",
#     "media",
#     "contracts",
#     "electronic",
#     "physical"
#   ],
#   "DM01": [
#     "also",
#     "mean",
#     "transferred",
#     "non-business",
#     "intervals",
#     "regular",
#     "sold",
#     "published",
#     "digital",
#     "ordinary",
#     "usual",
#     "works",
#     "electronically",
#     "files",
#     "magazine",
#     "version",
#     "use",
#     "magazines",
#     "printed",
#     "information",
#     "generally",
#     "identical",
#     "hard-copy",
#     "versions",
#     "sense",
#     "recognized"
#   ],
#   "DM02": [
#     "goods",
#     "digital",
#     "related",
#     "sales",
#     "lists",
#     "transferred",
#     "means",
#     "customer",
#     "list",
#     "information",
#     "electronic",
#     "mailing",
#     "otherwise"
#   ],
#   "DM03": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "movies",
#     "otherwise"
#   ],
#   "DM04": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "otherwise",
#     "music"
#   ],
#   "DN01": [
#     "also",
#     "mean",
#     "means",
#     "non-business",
#     "publications",
#     "daily",
#     "intervals",
#     "short",
#     "public",
#     "sold",
#     "edition",
#     "subscription",
#     "interest",
#     "transmitted",
#     "digital",
#     "access",
#     "customer",
#     "periodically",
#     "weekly",
#     "newspapers",
#     "print",
#     "version",
#     "use",
#     "commonly",
#     "newspaper",
#     "printed",
#     "dissemination",
#     "information",
#     "news",
#     "hard-copy",
#     "versions",
#     "\u2013",
#     "general",
#     "content",
#     "distributed",
#     "character",
#     "electronic",
#     "understood",
#     "similar"
#   ],
#   "DO01": [
#     "other",
#     "goods",
#     "digital",
#     "specifically",
#     "sales",
#     "transferred",
#     "means",
#     "customer",
#     "tax",
#     "media",
#     "another",
#     "identified",
#     "code",
#     "electronic",
#     "physical"
#   ],
#   "DP01": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "photographs",
#     "otherwise"
#   ],
#   "DV01": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "videos",
#     "electronic",
#     "otherwise"
#   ],
#   "DV02": [
#     "visual",
#     "audio",
#     "digital",
#     "works"
#   ],
#   "FR": [
#     "takes",
#     "fob",
#     "transferred",
#     "delivery",
#     "possession",
#     "backward",
#     "charges",
#     "goods",
#     "common",
#     "compatibility",
#     "time",
#     "customer",
#     "destination",
#     "seller",
#     "paid",
#     "product",
#     "title",
#     "shipping",
#     "third-party",
#     "carrier"
#   ],
#   "FR00": [
#     "freight",
#     "special",
#     "delivery",
#     "sold",
#     "charges",
#     "goods",
#     "customer",
#     "applicable",
#     "identified",
#     "seller",
#     "paid",
#     "handling",
#     "product",
#     "company",
#     "separately",
#     "shipping",
#     "represent",
#     "preparing",
#     "cost",
#     "transportation"
#   ],
#   "FR01": [
#     "party",
#     "charges",
#     "seller",
#     "products",
#     "rather",
#     "third",
#     "sold",
#     "imposed",
#     "service",
#     "product",
#     "delivery",
#     "company",
#     "using",
#     "transportation",
#     "vehicle"
#   ],
#   "FR02": [
#     "charges",
#     "paid",
#     "shipping",
#     "seller",
#     "common",
#     "represents",
#     "``",
#     "handling",
#     "third-party",
#     "additional",
#     "directly",
#     "carrier",
#     "product",
#     "without",
#     "cost",
#     "transportation",
#     "''"
#   ],
#   "FR03": [
#     "charges",
#     "paid",
#     "handling",
#     "shipping",
#     "seller",
#     "represents",
#     "``",
#     "additional",
#     "combined",
#     "special",
#     "cost",
#     "plus",
#     "transportation",
#     "''"
#   ],
#   "FR04": [
#     "separately",
#     "sale",
#     "charge",
#     "transfer",
#     "electronic",
#     "electronically",
#     "stated",
#     "associated",
#     "delivered"
#   ],
#   "FR05": [
#     "unloading",
#     "loading",
#     "freight"
#   ],
#   "FR06": [
#     "involve",
#     "goods",
#     "outside",
#     "international",
#     "place",
#     "service",
#     "freight",
#     "services",
#     "canada",
#     "transportation"
#   ],
#   "FR07": [
#     "charges",
#     "insurance",
#     "mandatory",
#     "shipments"
#   ],
#   "FR99": [
#     "limited",
#     "item",
#     "unmapped",
#     "charge",
#     "freight",
#     "cases",
#     "mapped",
#     "temporary",
#     "taxable",
#     "non-taxable",
#     "applicable",
#     "tax",
#     "system",
#     "associated",
#     "base",
#     "specific",
#     "using",
#     "sku",
#     "use",
#     "accurately",
#     "assigned",
#     "unless",
#     "impose",
#     "adequately",
#     "exemption",
#     "separately",
#     "purpose",
#     "reviewed",
#     "getting",
#     "entity",
#     "default",
#     "code",
#     "stated"
#   ],
#   "O000": [
#     "other",
#     "charges",
#     "sale",
#     "personal",
#     "viewed",
#     "property",
#     "performance",
#     "either",
#     "service",
#     "types",
#     "tangible",
#     "normally",
#     "miscellaneous"
#   ],
#   "O999": [
#     "unmapped",
#     "taxability",
#     "know",
#     "taxing",
#     "temporary",
#     "map",
#     "jurisdictions",
#     "taxable",
#     "used",
#     "tax",
#     "identified",
#     "system",
#     "specific",
#     "non-products",
#     "sku",
#     "service",
#     "product",
#     "purposes",
#     "this",
#     "states",
#     "default",
#     "code"
#   ],
#   "OA02": [
#     "parks",
#     "concerts",
#     "admission",
#     "cultural",
#     "may",
#     "sales",
#     "fees",
#     "amusement",
#     "note",
#     "events",
#     "tax",
#     "apply",
#     "entertainment",
#     "admissions",
#     "series",
#     "considers",
#     "excludes",
#     "sporting",
#     "code"
#   ],
#   "OC03": [
#     "party",
#     "coupons",
#     "third"
#   ],
#   "OC04": [
#     "fee",
#     "convenience",
#     "online",
#     "reservation",
#     "associated"
#   ],
#   "OD01": [
#     "vendor",
#     "payment",
#     "early",
#     "cash",
#     "opposed",
#     "discounts"
#   ],
#   "OD02": [
#     "make",
#     "fee",
#     "right",
#     "goods",
#     "dues",
#     "dues/membership",
#     "tpp",
#     "fees",
#     "could",
#     "include",
#     "membership",
#     "transfer",
#     "purchase",
#     "reduced",
#     "purchases",
#     "services",
#     "including"
#   ],
#   "OD03": [
#     "membership",
#     "cards",
#     "discount"
#   ],
#   "OE01": [
#     "similar",
#     "exchange/trade-ins",
#     "items"
#   ],
#   "OF02": [
#     "cancellation",
#     "fees"
#   ],
#   "OF03": [
#     "fees",
#     "expedite"
#   ],
#   "OF04": [
#     "sale",
#     "item",
#     "extension",
#     "transaction",
#     "certain",
#     "may",
#     "recurring",
#     "otherwise",
#     "original",
#     "interest",
#     "charges",
#     "jurisdictions",
#     "taxable",
#     "based",
#     "note",
#     "purchaser",
#     "charged",
#     "seller",
#     "exempt",
#     "financed",
#     "one-time",
#     "credit",
#     "fee",
#     "code",
#     "presumes"
#   ],
#   "OF05": [
#     "fee",
#     "batteries",
#     "charge",
#     "core",
#     "refundable",
#     "deposit"
#   ],
#   "OF06": [
#     "separately",
#     "credit",
#     "charged",
#     "charges",
#     "retailer",
#     "card",
#     "fees",
#     "customer",
#     "stated",
#     "passed",
#     "processing"
#   ],
#   "OF07": [
#     "charged",
#     "marketplace",
#     "property",
#     "facilitated",
#     "commissions",
#     "sales",
#     "lodging",
#     "fees",
#     "facilitator",
#     "tangible",
#     "services",
#     "personal"
#   ],
#   "OH01": [
#     "separately",
#     "charges",
#     "handling",
#     "shipping",
#     "identified"
#   ],
#   "OL01": [
#     "property",
#     "commercial",
#     "use",
#     "boat",
#     "access",
#     "concessionaire",
#     "estate",
#     "license",
#     "mailbox",
#     "real",
#     "kitchen",
#     "facilities",
#     "restricted",
#     "launch"
#   ],
#   "OM01": [
#     "made",
#     "donation",
#     "event",
#     "organization",
#     "place",
#     "charitable",
#     "amusement",
#     "admission",
#     "sporting",
#     "exchange",
#     "etc",
#     "voluntarily",
#     "monetary"
#   ],
#   "ON01": [
#     "deposits",
#     "non-refundable"
#   ],
#   "ON03": [
#     "used",
#     "user",
#     "associated",
#     "conducted",
#     "exempt",
#     "non-taxable",
#     "transaction",
#     "due",
#     "diligence",
#     "tax",
#     "this",
#     "code",
#     "default",
#     "system",
#     "determine",
#     "transactions"
#   ],
#   "OO02": [
#     "occasional",
#     "sales"
#   ],
#   "OR04": [
#     "fees",
#     "restocking"
#   ],
#   "OR07": [
#     "name",
#     "charge",
#     "economic",
#     "value",
#     "?",
#     "one",
#     "payment",
#     "sales",
#     "measurable",
#     "based",
#     "fees",
#     "time",
#     "etc",
#     "copyright",
#     "periodic",
#     "paid",
#     "use",
#     "patent",
#     "royalty",
#     "trademark",
#     "someone"
#   ],
#   "OT01": [
#     "prewritten",
#     "hotel",
#     "software",
#     "charges",
#     "expenses",
#     "related",
#     "etc",
#     "services",
#     "associated",
#     "-associated",
#     "seller",
#     "installation",
#     "seeking",
#     "rental",
#     "costs",
#     "car",
#     "air",
#     "implementation",
#     "reimbursed",
#     "travel"
#   ],
#   "P000": [
#     "made",
#     "limit",
#     "property",
#     "number",
#     "deemed",
#     "user",
#     "consequently",
#     "tpp",
#     "taxability",
#     "nature",
#     "tangible",
#     "and/or",
#     "used",
#     "taxable",
#     "etc",
#     "non-taxable",
#     "local",
#     "statutes",
#     "tax",
#     "applicable",
#     "codes",
#     "system",
#     "associated",
#     "specific",
#     "personal",
#     "use",
#     "land",
#     "specifically",
#     "individual",
#     "buildings",
#     "unless",
#     "could",
#     "available",
#     "known",
#     "state",
#     "additionally",
#     "generally",
#     "products",
#     "items",
#     "want",
#     "default",
#     "real",
#     "code",
#     "presumption"
#   ],
#   "P999": [
#     "unmapped",
#     "tpp",
#     "taxability",
#     "taxing",
#     "temporary",
#     "map",
#     "jurisdictions",
#     "taxable",
#     "used",
#     "tax",
#     "identified",
#     "system",
#     "specific",
#     "sku",
#     "known",
#     "product",
#     "purposes",
#     "this",
#     "products",
#     "default",
#     "code"
#   ],
#   "PA02": [
#     "agricultural"
#   ]
# }
# {
#   "D0000000": [
#     "transferred",
#     "computer",
#     "software",
#     "photographs",
#     "otherwise",
#     "music",
#     "sold",
#     "goods",
#     "digital",
#     "viewed",
#     "include",
#     "would",
#     "electronically",
#     "files",
#     "pdfs",
#     "artwork",
#     "movies",
#     "generally",
#     "websites",
#     "e-books",
#     "downloadable",
#     "items",
#     "examples",
#     "zip"
#   ],
#   "D9999999": [
#     "limited",
#     "unmapped",
#     "cases",
#     "mapped",
#     "temporary",
#     "goods",
#     "digital",
#     "taxable",
#     "applicable",
#     "tax",
#     "system",
#     "base",
#     "specific",
#     "using",
#     "sku",
#     "use",
#     "accurately",
#     "assigned",
#     "unless",
#     "impose",
#     "adequately",
#     "exemption",
#     "purpose",
#     "reviewed",
#     "good",
#     "getting",
#     "entity",
#     "default",
#     "code"
#   ],
#   "DA010000": [
#     "property",
#     "designs",
#     "transferred",
#     "means",
#     "tangible",
#     "advertising",
#     "goods",
#     "digital",
#     "etc",
#     "customer",
#     "services",
#     "associated",
#     "personal",
#     "artwork",
#     "media",
#     "photos",
#     "physical",
#     "material",
#     "electronic"
#   ],
#   "DA030000": [
#     "goods",
#     "digital",
#     "transferred",
#     "canned",
#     "customer",
#     "artwork",
#     "art",
#     "means",
#     "electronic",
#     "media",
#     "physical"
#   ],
#   "DA040000": [
#     "audio",
#     "goods",
#     "digital",
#     "spoken",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "media",
#     "word",
#     "physical",
#     "music"
#   ],
#   "DA040100": [
#     "satellite",
#     "subscriptions",
#     "services",
#     "radio"
#   ],
#   "DA050000": [
#     "audio",
#     "digital",
#     "works"
#   ],
#   "DA051011": [
#     "rights",
#     "audio",
#     "digital",
#     "use",
#     "user",
#     "end",
#     "works",
#     "permanent",
#     "sold"
#   ],
#   "DA051012": [
#     "audio",
#     "digital",
#     "payments",
#     "works",
#     "continued",
#     "conditioned",
#     "rights"
#   ],
#   "DA051013": [
#     "audio",
#     "digital",
#     "user",
#     "end",
#     "works",
#     "users",
#     "sold"
#   ],
#   "DA059399": [
#     "audio",
#     "digital",
#     "use",
#     "works",
#     "permanent",
#     "less",
#     "rights"
#   ],
#   "DB010000": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "blueprints",
#     "electronic",
#     "media",
#     "physical"
#   ],
#   "DB020000": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "media",
#     "physical",
#     "books"
#   ],
#   "DB031000": [
#     "digital",
#     "books"
#   ],
#   "DB031013": [
#     "rights",
#     "digital",
#     "use",
#     "user",
#     "end",
#     "permanent",
#     "books",
#     "sold"
#   ],
#   "DB031014": [
#     "digital",
#     "use",
#     "books",
#     "permanent",
#     "less",
#     "rights"
#   ],
#   "DB031015": [
#     "digital",
#     "books",
#     "payments",
#     "continued",
#     "conditioned",
#     "rights"
#   ],
#   "DB031016": [
#     "digital",
#     "user",
#     "books",
#     "end",
#     "users",
#     "sold"
#   ],
#   "DC010000": [
#     "user",
#     "transferred",
#     "non-business",
#     "load",
#     "computer",
#     "software",
#     "sold",
#     "business-to-business",
#     "forms",
#     "end",
#     "operation",
#     "customer",
#     "electronically",
#     "various",
#     "``",
#     "either",
#     "media",
#     "leave",
#     "physical",
#     "business",
#     "''"
#   ],
#   "DC010100": [
#     "deemed",
#     "transferred",
#     "canned",
#     "computer",
#     "software",
#     "written",
#     "minor",
#     "business-to-business",
#     "customized",
#     "custom",
#     "customer",
#     "modification",
#     "individual",
#     "specifications",
#     "media",
#     "merely",
#     "physical",
#     "'s",
#     "add-on"
#   ],
#   "DC010200": [
#     "deemed",
#     "transferred",
#     "canned",
#     "computer",
#     "software",
#     "form",
#     "written",
#     "minor",
#     "business-to-business",
#     "customized",
#     "custom",
#     "customer",
#     "modification",
#     "electronically",
#     "individual",
#     "downloaded",
#     "specifications",
#     "media",
#     "merely",
#     "physical",
#     "rather",
#     "'s",
#     "add-on"
#   ],
#   "DC010300": [
#     "deemed",
#     "canned",
#     "load",
#     "computer",
#     "software",
#     "written",
#     "minor",
#     "business-to-business",
#     "on-site",
#     "customized",
#     "custom",
#     "customer",
#     "modification",
#     "individual",
#     "specifications",
#     "media",
#     "leave",
#     "merely",
#     "actual",
#     "physical",
#     "'s",
#     "left",
#     "loaded",
#     "add-on"
#   ],
#   "DC010400": [
#     "business-to-business",
#     "customized",
#     "transferred",
#     "computer",
#     "software",
#     "media",
#     "prewritten/canned",
#     "physical"
#   ],
#   "DC010500": [
#     "business-to-business",
#     "customized",
#     "downloaded",
#     "transferred",
#     "computer",
#     "software",
#     "prewritten/canned",
#     "electronically"
#   ],
#   "DC010600": [
#     "via",
#     "business-to-business",
#     "'s",
#     "on-site",
#     "left",
#     "customized",
#     "loaded",
#     "customer",
#     "load",
#     "computer",
#     "software",
#     "prewritten/canned",
#     "leave",
#     "media",
#     "delivered",
#     "actual",
#     "physical"
#   ],
#   "DC011000": [
#     "e.g",
#     "'s",
#     "systems",
#     "operating",
#     "operation",
#     "integral",
#     "computer",
#     "software",
#     "system"
#   ],
#   "DC020000": [
#     "user",
#     "transferred",
#     "non-business",
#     "load",
#     "computer",
#     "software",
#     "sold",
#     "forms",
#     "business-to-customer",
#     "end",
#     "customer",
#     "electronically",
#     "various",
#     "``",
#     "either",
#     "media",
#     "leave",
#     "physical",
#     "business",
#     "''"
#   ],
#   "DC020100": [
#     "deemed",
#     "transferred",
#     "canned",
#     "computer",
#     "software",
#     "written",
#     "minor",
#     "customized",
#     "business-to-customer",
#     "custom",
#     "customer",
#     "modification",
#     "individual",
#     "specifications",
#     "media",
#     "merely",
#     "physical",
#     "'s",
#     "add-on"
#   ],
#   "DC020200": [
#     "deemed",
#     "transferred",
#     "canned",
#     "computer",
#     "software",
#     "form",
#     "written",
#     "minor",
#     "customized",
#     "business-to-customer",
#     "custom",
#     "customer",
#     "modification",
#     "electronically",
#     "individual",
#     "downloaded",
#     "specifications",
#     "media",
#     "merely",
#     "physical",
#     "rather",
#     "'s",
#     "add-on"
#   ],
#   "DC020300": [
#     "deemed",
#     "canned",
#     "load",
#     "computer",
#     "software",
#     "written",
#     "minor",
#     "on-site",
#     "customized",
#     "business-to-customer",
#     "custom",
#     "customer",
#     "modification",
#     "individual",
#     "specifications",
#     "media",
#     "leave",
#     "merely",
#     "actual",
#     "physical",
#     "'s",
#     "left",
#     "loaded",
#     "add-on"
#   ],
#   "DC020400": [
#     "customized",
#     "business-to-customer",
#     "transferred",
#     "computer",
#     "software",
#     "media",
#     "prewritten/canned",
#     "physical"
#   ],
#   "DC020402": [
#     "educational",
#     "business-to-business",
#     "way",
#     "customized",
#     "transferred",
#     "non-educational",
#     "primarily",
#     "academic",
#     "computer",
#     "software",
#     "prewritten/canned",
#     "media",
#     "purposes",
#     "designed",
#     "physical",
#     "something"
#   ],
#   "DC020500": [
#     "customized",
#     "downloaded",
#     "business-to-customer",
#     "transferred",
#     "computer",
#     "software",
#     "prewritten/canned",
#     "electronically"
#   ],
#   "DC020501": [
#     "educational",
#     "business-to-business",
#     "customized",
#     "downloaded",
#     "transferred",
#     "primarily",
#     "academic",
#     "computer",
#     "software",
#     "prewritten/canned",
#     "electronically",
#     "purposes",
#     "designed"
#   ],
#   "DC020502": [
#     "educational",
#     "customized",
#     "downloaded",
#     "business-to-customer",
#     "transferred",
#     "non-educational",
#     "primarily",
#     "academic",
#     "computer",
#     "software",
#     "prewritten/canned",
#     "electronically",
#     "purposes",
#     "designed",
#     "something"
#   ],
#   "DC020503": [
#     "business-to-business",
#     "downloaded",
#     "non-educational",
#     "computer",
#     "software",
#     "prewritten/canned",
#     "electronically"
#   ],
#   "DC020600": [
#     "via",
#     "'s",
#     "left",
#     "customized",
#     "loaded",
#     "business-to-customer",
#     "customer",
#     "load",
#     "computer",
#     "software",
#     "prewritten/canned",
#     "leave",
#     "media",
#     "delivered",
#     "actual",
#     "physical",
#     "onsite"
#   ],
#   "DC060000": [
#     "previously",
#     "fee",
#     "renewals",
#     "canned",
#     "license",
#     "software",
#     "periodic",
#     "license-to-use",
#     "purchased"
#   ],
#   "DC070000": [
#     "cloud/remote",
#     "storage"
#   ],
#   "DD020000": [
#     "plans",
#     "goods",
#     "digital",
#     "designs",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "media",
#     "physical"
#   ],
#   "DD040000": [
#     "other",
#     "documentation",
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "tax",
#     "media",
#     "specific",
#     "identified",
#     "code",
#     "electronic",
#     "physical"
#   ],
#   "DG010000": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "games",
#     "otherwise"
#   ],
#   "DG010100": [
#     "goods",
#     "digital",
#     "standard",
#     "transferred",
#     "means",
#     "customer",
#     "media",
#     "games",
#     "games-physical",
#     "physical"
#   ],
#   "DG010200": [
#     "games-streaming",
#     "goods",
#     "digital",
#     "games",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "download"
#   ],
#   "DG010201": [
#     "made",
#     "chicago",
#     "transferred",
#     "means",
#     "games",
#     "otherwise",
#     "temporary",
#     "interest",
#     "on-line",
#     "customer",
#     "amusement",
#     "note",
#     "tax",
#     "description",
#     "apply",
#     "transactions",
#     "use",
#     "streaming",
#     "applies",
#     "purposes",
#     "ownership",
#     "participating",
#     "addresses",
#     "see",
#     "additional",
#     "non-possessory",
#     "electronic",
#     "code",
#     "download"
#   ],
#   "DG010300": [
#     "download",
#     "electronic",
#     "permanent",
#     "games",
#     "ownership"
#   ],
#   "DG010301": [
#     "streaming",
#     "download",
#     "electronic",
#     "permanent",
#     "games",
#     "less",
#     "ownership"
#   ],
#   "DG010302": [
#     "made",
#     "addresses",
#     "use",
#     "streaming",
#     "download",
#     "chicago",
#     "amusement",
#     "note",
#     "electronic",
#     "apply",
#     "permanent",
#     "code",
#     "games",
#     "less",
#     "ownership",
#     "tax",
#     "transactions"
#   ],
#   "DG020000": [
#     "cards",
#     "electronically-delivered",
#     "gift"
#   ],
#   "DI010000": [
#     "digital",
#     "images",
#     "birth",
#     "transferred",
#     "invoices",
#     "etc",
#     "customer",
#     "means",
#     "electronic",
#     "certificates",
#     "otherwise"
#   ],
#   "DI010100": [
#     "digital",
#     "standard",
#     "images",
#     "transferred",
#     "images-physical",
#     "customer",
#     "means",
#     "media",
#     "physical"
#   ],
#   "DI010200": [
#     "images-streaming",
#     "digital",
#     "images",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "download"
#   ],
#   "DI010201": [
#     "made",
#     "possessory",
#     "chicago",
#     "transferred",
#     "means",
#     "privilege",
#     "permanent",
#     "delivered",
#     "granted",
#     "subscription",
#     "interest",
#     "digital",
#     "customer",
#     "amusement",
#     "note",
#     "tax",
#     "description",
#     "electronically",
#     "television",
#     "apply",
#     "transactions",
#     "use",
#     "shows",
#     "images",
#     "streaming",
#     "pay-per-view",
#     "purposes",
#     "videos",
#     "movies",
#     "wherein",
#     "title",
#     "addresses",
#     "see",
#     "watching",
#     "additional",
#     "electronic",
#     "code",
#     "download"
#   ],
#   "DL020000": [
#     "wills",
#     "documentation",
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "etc",
#     "customer",
#     "legal",
#     "media",
#     "contracts",
#     "electronic",
#     "physical"
#   ],
#   "DM010100": [
#     "also",
#     "mean",
#     "transferred",
#     "non-business",
#     "intervals",
#     "regular",
#     "sold",
#     "published",
#     "digital",
#     "ordinary",
#     "usual",
#     "works",
#     "electronically",
#     "files",
#     "magazine",
#     "version",
#     "use",
#     "magazines",
#     "printed",
#     "information",
#     "generally",
#     "identical",
#     "hard-copy",
#     "versions",
#     "sense",
#     "recognized"
#   ],
#   "DM020000": [
#     "goods",
#     "digital",
#     "related",
#     "sales",
#     "lists",
#     "transferred",
#     "means",
#     "customer",
#     "list",
#     "information",
#     "electronic",
#     "mailing",
#     "otherwise"
#   ],
#   "DM020100": [
#     "lists-physical",
#     "goods",
#     "digital",
#     "standard",
#     "transferred",
#     "means",
#     "customer",
#     "list",
#     "media",
#     "mailing",
#     "physical"
#   ],
#   "DM020200": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "lists-streaming",
#     "list",
#     "download",
#     "mailing"
#   ],
#   "DM030000": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "movies",
#     "otherwise"
#   ],
#   "DM030100": [
#     "goods",
#     "digital",
#     "standard",
#     "transferred",
#     "means",
#     "customer",
#     "movies",
#     "media",
#     "movies-physical",
#     "physical"
#   ],
#   "DM030200": [
#     "movies-streaming",
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "movies",
#     "download"
#   ],
#   "DM030201": [
#     "made",
#     "possessory",
#     "chicago",
#     "transferred",
#     "means",
#     "privilege",
#     "permanent",
#     "delivered",
#     "granted",
#     "subscription",
#     "interest",
#     "customer",
#     "amusement",
#     "note",
#     "tax",
#     "description",
#     "electronically",
#     "television",
#     "apply",
#     "transactions",
#     "use",
#     "shows",
#     "streaming",
#     "pay-per-view",
#     "purposes",
#     "videos",
#     "movies",
#     "wherein",
#     "title",
#     "addresses",
#     "see",
#     "watching",
#     "additional",
#     "electronic",
#     "code",
#     "download"
#   ],
#   "DM040000": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "otherwise",
#     "music"
#   ],
#   "DM040100": [
#     "goods",
#     "digital",
#     "standard",
#     "music-physical",
#     "transferred",
#     "means",
#     "customer",
#     "media",
#     "physical",
#     "music"
#   ],
#   "DM040200": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "music-streaming",
#     "download",
#     "music"
#   ],
#   "DM040201": [
#     "made",
#     "possessory",
#     "chicago",
#     "transferred",
#     "means",
#     "privilege",
#     "permanent",
#     "delivered",
#     "granted",
#     "music",
#     "subscription",
#     "interest",
#     "customer",
#     "amusement",
#     "note",
#     "tax",
#     "description",
#     "electronically",
#     "apply",
#     "transactions",
#     "listening",
#     "use",
#     "streaming",
#     "purposes",
#     "wherein",
#     "title",
#     "addresses",
#     "see",
#     "additional",
#     "electronic",
#     "code",
#     "download"
#   ],
#   "DN010000": [
#     "also",
#     "mean",
#     "means",
#     "non-business",
#     "publications",
#     "daily",
#     "intervals",
#     "short",
#     "public",
#     "sold",
#     "edition",
#     "subscription",
#     "interest",
#     "transmitted",
#     "digital",
#     "access",
#     "customer",
#     "periodically",
#     "weekly",
#     "newspapers",
#     "print",
#     "version",
#     "use",
#     "commonly",
#     "newspaper",
#     "printed",
#     "dissemination",
#     "information",
#     "news",
#     "hard-copy",
#     "versions",
#     "\u2013",
#     "general",
#     "content",
#     "distributed",
#     "character",
#     "electronic",
#     "understood",
#     "similar"
#   ],
#   "DO010000": [
#     "other",
#     "goods",
#     "digital",
#     "specifically",
#     "sales",
#     "transferred",
#     "means",
#     "customer",
#     "tax",
#     "media",
#     "another",
#     "identified",
#     "code",
#     "electronic",
#     "physical"
#   ],
#   "DP010000": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "electronic",
#     "photographs",
#     "otherwise"
#   ],
#   "DP010100": [
#     "goods",
#     "digital",
#     "standard",
#     "transferred",
#     "means",
#     "customer",
#     "media",
#     "physical",
#     "photographs",
#     "photographs-physical"
#   ],
#   "DP010200": [
#     "photographs-streaming",
#     "transferred",
#     "means",
#     "delivery",
#     "photographs",
#     "may",
#     "jurisdictions",
#     "goods",
#     "digital",
#     "customer",
#     "note",
#     "invoice",
#     "``",
#     "exemption",
#     "qualify",
#     "electronic",
#     "stated",
#     "download",
#     "required",
#     "''"
#   ],
#   "DP010201": [
#     "made",
#     "possessory",
#     "chicago",
#     "transferred",
#     "means",
#     "privilege",
#     "permanent",
#     "photographs",
#     "delivered",
#     "granted",
#     "subscription",
#     "interest",
#     "customer",
#     "amusement",
#     "note",
#     "tax",
#     "description",
#     "electronically",
#     "television",
#     "apply",
#     "transactions",
#     "use",
#     "shows",
#     "streaming",
#     "pay-per-view",
#     "purposes",
#     "videos",
#     "movies",
#     "wherein",
#     "title",
#     "addresses",
#     "see",
#     "watching",
#     "additional",
#     "electronic",
#     "code",
#     "download"
#   ],
#   "DV010000": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "videos",
#     "electronic",
#     "otherwise"
#   ],
#   "DV010100": [
#     "goods",
#     "digital",
#     "standard",
#     "transferred",
#     "means",
#     "customer",
#     "videos-physical",
#     "videos",
#     "media",
#     "physical"
#   ],
#   "DV010200": [
#     "goods",
#     "digital",
#     "transferred",
#     "means",
#     "customer",
#     "videos",
#     "electronic",
#     "download",
#     "videos-streaming"
#   ],
#   "DV010201": [
#     "made",
#     "possessory",
#     "chicago",
#     "transferred",
#     "means",
#     "privilege",
#     "permanent",
#     "delivered",
#     "granted",
#     "subscription",
#     "interest",
#     "customer",
#     "amusement",
#     "note",
#     "tax",
#     "description",
#     "electronically",
#     "television",
#     "apply",
#     "transactions",
#     "use",
#     "shows",
#     "streaming",
#     "pay-per-view",
#     "videos",
#     "purposes",
#     "movies",
#     "wherein",
#     "title",
#     "addresses",
#     "see",
#     "watching",
#     "additional",
#     "electronic",
#     "code",
#     "download"
#   ],
#   "DV017194": [
#     "type",
#     "video",
#     "please",
#     "delivery",
#     "depending",
#     "facilities",
#     "may",
#     "protocol",
#     "cable",
#     "on-demand",
#     "include",
#     "note",
#     "television",
#     "services",
#     "streamed",
#     "cable-related",
#     "programming",
#     "streaming",
#     "regard",
#     "service",
#     "state",
#     "internet",
#     "wireline",
#     "subscribers",
#     "taxes",
#     "provided",
#     "wireless",
#     "prepaid",
#     "without",
#     "satellite",
#     "subject",
#     "code",
#     "technology",
#     "broadcasts"
#   ],
#   "DV021000": [
#     "visual",
#     "audio",
#     "digital",
#     "works"
#   ],
#   "DV021007": [
#     "visual",
#     "rights",
#     "audio",
#     "digital",
#     "use",
#     "user",
#     "end",
#     "works",
#     "permanent",
#     "sold"
#   ],
#   "DV021008": [
#     "visual",
#     "audio",
#     "digital",
#     "use",
#     "works",
#     "permanent",
#     "less",
#     "rights"
#   ],
#   "DV021009": [
#     "visual",
#     "audio",
#     "digital",
#     "payments",
#     "works",
#     "continued",
#     "conditioned",
#     "rights"
#   ],
#   "DV021010": [
#     "made",
#     "visual",
#     "avatax",
#     "possessory",
#     "chicago",
#     "transferred",
#     "means",
#     "permanent",
#     "privilege",
#     "delivered",
#     "granted",
#     "subscription",
#     "interest",
#     "audio",
#     "digital",
#     "customer",
#     "amusement",
#     "note",
#     "tax",
#     "works",
#     "electronically",
#     "television",
#     "system",
#     "apply",
#     "transactions",
#     "use",
#     "shows",
#     "streaming",
#     "pay-per-view",
#     "videos",
#     "purposes",
#     "information",
#     "movies",
#     "wherein",
#     "title",
#     "addresses",
#     "see",
#     "watching",
#     "additional",
#     "electronic",
#     "code",
#     "less",
#     "rights"
#   ],
#   "DV029398": [
#     "visual",
#     "users",
#     "audio",
#     "digital",
#     "user",
#     "end",
#     "works",
#     "sold"
#   ],
#   "FR": [
#     "takes",
#     "fob",
#     "transferred",
#     "delivery",
#     "possession",
#     "backward",
#     "charges",
#     "goods",
#     "common",
#     "compatibility",
#     "time",
#     "customer",
#     "destination",
#     "seller",
#     "paid",
#     "product",
#     "title",
#     "shipping",
#     "third-party",
#     "carrier"
#   ],
#   "FR000000": [
#     "freight",
#     "special",
#     "delivery",
#     "sold",
#     "charges",
#     "goods",
#     "customer",
#     "applicable",
#     "identified",
#     "seller",
#     "paid",
#     "handling",
#     "product",
#     "company",
#     "separately",
#     "shipping",
#     "represent",
#     "preparing",
#     "cost",
#     "transportation"
#   ],
#   "FR010000": [
#     "party",
#     "charges",
#     "seller",
#     "products",
#     "rather",
#     "third",
#     "sold",
#     "imposed",
#     "service",
#     "product",
#     "delivery",
#     "company",
#     "using",
#     "transportation",
#     "vehicle"
#   ],
#   "FR010100": [
#     "takes",
#     "passage",
#     "fob",
#     "delivery",
#     "possession",
#     "sold",
#     "charges",
#     "customer",
#     "using",
#     "destination",
#     "vehicle",
#     "seller",
#     "take",
#     "imposed",
#     "service",
#     "product",
#     "transfer",
#     "company",
#     "title",
#     "rather",
#     "third-party",
#     "place",
#     "transportation"
#   ],
#   "FR010200": [
#     "takes",
#     "origin",
#     "passage",
#     "fob",
#     "delivery",
#     "sold",
#     "charges",
#     "customer",
#     "using",
#     "vehicle",
#     "seller",
#     "prior",
#     "imposed",
#     "service",
#     "product",
#     "transfer",
#     "company",
#     "title",
#     "rather",
#     "third-party",
#     "place",
#     "transportation"
#   ],
#   "FR020000": [
#     "charges",
#     "paid",
#     "shipping",
#     "seller",
#     "common",
#     "represents",
#     "``",
#     "handling",
#     "third-party",
#     "additional",
#     "directly",
#     "carrier",
#     "product",
#     "without",
#     "cost",
#     "transportation",
#     "''"
#   ],
#   "FR020100": [
#     "takes",
#     "charges",
#     "paid",
#     "shipping",
#     "seller",
#     "common",
#     "goods",
#     "fob",
#     "third-party",
#     "title",
#     "transferred",
#     "product",
#     "carrier",
#     "delivery",
#     "time",
#     "customer",
#     "possession",
#     "destination"
#   ],
#   "FR020200": [
#     "charges",
#     "paid",
#     "shipping",
#     "origin",
#     "common",
#     "seller",
#     "sales",
#     "fob",
#     "third-party",
#     "prior",
#     "transferred",
#     "product",
#     "carrier",
#     "delivery",
#     "time",
#     "shipment",
#     "title"
#   ],
#   "FR020400": [
#     "takes",
#     "charges",
#     "paid",
#     "shipping",
#     "seller",
#     "goods",
#     "fob",
#     "third-party",
#     "title",
#     "transferred",
#     "non-common",
#     "carrier",
#     "delivery",
#     "product",
#     "time",
#     "customer",
#     "possession",
#     "destination"
#   ],
#   "FR020500": [
#     "charges",
#     "paid",
#     "shipping",
#     "origin",
#     "seller",
#     "sales",
#     "fob",
#     "third-party",
#     "prior",
#     "transferred",
#     "non-common",
#     "carrier",
#     "delivery",
#     "product",
#     "time",
#     "shipment",
#     "title"
#   ],
#   "FR020800": [
#     "exceeds",
#     "transporting",
#     "charges",
#     "shipping",
#     "exceed",
#     "``",
#     "product",
#     "customer",
#     "delivery",
#     "cost",
#     "actual",
#     "''"
#   ],
#   "FR020900": [
#     "exceeds",
#     "charges",
#     "shipping",
#     "exceed",
#     "deemed",
#     "``",
#     "reasonable",
#     "rates",
#     "prevailing",
#     "''"
#   ],
#   "FR021004": [
#     "direct",
#     "postage",
#     "mail"
#   ],
#   "FR022000": [
#     "separately",
#     "option",
#     "shipping",
#     "origin",
#     "fob",
#     "\u2013",
#     "customer",
#     "contract"
#   ],
#   "FR030000": [
#     "charges",
#     "paid",
#     "handling",
#     "shipping",
#     "seller",
#     "represents",
#     "``",
#     "additional",
#     "combined",
#     "special",
#     "cost",
#     "plus",
#     "transportation",
#     "''"
#   ],
#   "FR030700": [
#     "handling-direct",
#     "shipping",
#     "mail-printed",
#     "material",
#     "delivery",
#     "mass",
#     "audience"
#   ],
#   "FR040000": [
#     "separately",
#     "sale",
#     "charge",
#     "transfer",
#     "electronic",
#     "electronically",
#     "stated",
#     "associated",
#     "delivered"
#   ],
#   "FR059314": [
#     "unloading",
#     "loading",
#     "freight"
#   ],
#   "FR060000": [
#     "involve",
#     "goods",
#     "outside",
#     "international",
#     "place",
#     "service",
#     "freight",
#     "services",
#     "canada",
#     "transportation"
#   ],
#   "FR070100": [
#     "charges",
#     "insurance",
#     "mandatory",
#     "shipments"
#   ],
#   "FR999999": [
#     "limited",
#     "item",
#     "unmapped",
#     "charge",
#     "freight",
#     "cases",
#     "mapped",
#     "temporary",
#     "taxable",
#     "non-taxable",
#     "applicable",
#     "tax",
#     "system",
#     "associated",
#     "base",
#     "specific",
#     "using",
#     "sku",
#     "use",
#     "accurately",
#     "assigned",
#     "unless",
#     "impose",
#     "adequately",
#     "exemption",
#     "separately",
#     "purpose",
#     "reviewed",
#     "getting",
#     "entity",
#     "default",
#     "code",
#     "stated"
#   ],
#   "O0000000": [
#     "other",
#     "charges",
#     "sale",
#     "personal",
#     "viewed",
#     "property",
#     "performance",
#     "either",
#     "service",
#     "types",
#     "tangible",
#     "normally",
#     "miscellaneous"
#   ],
#   "O9999999": [
#     "unmapped",
#     "taxability",
#     "know",
#     "taxing",
#     "temporary",
#     "map",
#     "jurisdictions",
#     "taxable",
#     "used",
#     "tax",
#     "identified",
#     "system",
#     "specific",
#     "non-products",
#     "sku",
#     "service",
#     "product",
#     "purposes",
#     "this",
#     "states",
#     "default",
#     "code"
#   ],
#   "OA020000": [
#     "parks",
#     "concerts",
#     "admission",
#     "cultural",
#     "may",
#     "sales",
#     "fees",
#     "amusement",
#     "note",
#     "events",
#     "tax",
#     "apply",
#     "entertainment",
#     "admissions",
#     "series",
#     "considers",
#     "excludes",
#     "sporting",
#     "code"
#   ],
#   "OA020100": [
#     "admissions-amusement",
#     "parks"
#   ],
#   "OA020200": [
#     "admissions-concerts"
#   ],
#   "OA020300": [
#     "includes",
#     "admissions-other",
#     "amusement",
#     "entertainment"
#   ],
#   "OA020310": [
#     "adult",
#     "entertainment",
#     "admissions"
#   ],
#   "OA020400": [
#     "admissions-sporting",
#     "events"
#   ],
#   "OA020401": [
#     "race",
#     "horse",
#     "admissions"
#   ],
#   "OA020402": [
#     "sports",
#     "admissions",
#     "combative"
#   ],
#   "OA020403": [
#     "motorsports",
#     "admissions"
#   ],
#   "OA020500": [
#     "admissions-other",
#     "include",
#     "amusement",
#     "entertainment"
#   ],
#   "OA020600": [
#     "course",
#     "fees",
#     "admissions",
#     "municipally",
#     "owned",
#     "green",
#     "golf"
#   ],
#   "OA020700": [
#     "privately",
#     "course",
#     "fees",
#     "admissions",
#     "owned",
#     "green",
#     "golf"
#   ],
#   "OA020800": [
#     "theatrical/cinematic",
#     "admissions"
#   ],
#   "OA020801": [
#     "movies",
#     "admissions"
#   ],
#   "OA026346": [
#     "domino",
#     "billiards",
#     "admissions",
#     "pool",
#     "parlors"
#   ],
#   "OA029338": [
#     "sports",
#     "admissions",
#     "participatory",
#     "games"
#   ],
#   "OA029339": [
#     "bowling",
#     "admissions",
#     "alley"
#   ],
#   "OA029340": [
#     "bingo",
#     "admissions",
#     "game"
#   ],
#   "OC030000": [
#     "party",
#     "coupons",
#     "third"
#   ],
#   "OC040000": [
#     "fee",
#     "convenience",
#     "online",
#     "reservation",
#     "associated"
#   ],
#   "OC040100": [
#     "sale",
#     "fee",
#     "convenience",
#     "course",
#     "fees",
#     "municipally",
#     "owned",
#     "green",
#     "associated",
#     "golf"
#   ],
#   "OC040200": [
#     "sale",
#     "fee",
#     "convenience",
#     "privately",
#     "course",
#     "fees",
#     "owned",
#     "green",
#     "associated",
#     "golf"
#   ],
#   "OD010000": [
#     "vendor",
#     "payment",
#     "early",
#     "cash",
#     "opposed",
#     "discounts"
#   ],
#   "OD010300": [
#     "tpp",
#     "discounts"
#   ],
#   "OD010400": [
#     "ensure",
#     "proper",
#     "entry",
#     "taxable",
#     "calculation",
#     "item",
#     "amount",
#     "discount",
#     "requires",
#     "tax",
#     "negative",
#     "manufacturer",
#     "instant-off",
#     "rebate"
#   ],
#   "OD020000": [
#     "make",
#     "fee",
#     "right",
#     "goods",
#     "dues",
#     "dues/membership",
#     "tpp",
#     "fees",
#     "could",
#     "include",
#     "membership",
#     "transfer",
#     "purchase",
#     "reduced",
#     "purchases",
#     "services",
#     "including"
#   ],
#   "OD020320": [
#     "club",
#     "dues/membership",
#     "tpp",
#     "transfer",
#     "retail",
#     "shopping"
#   ],
#   "OD020400": [
#     "subscription",
#     "magazine",
#     "comes",
#     "dues/membership",
#     "tpp",
#     "transfer",
#     "membership",
#     "guarantees"
#   ],
#   "OD020500": [
#     "fraternal",
#     "dues",
#     "non-entertainment",
#     "social"
#   ],
#   "OD030000": [
#     "membership",
#     "cards",
#     "discount"
#   ],
#   "OE010100": [
#     "similar",
#     "exchange/trade-ins",
#     "items"
#   ],
#   "OF020000": [
#     "cancellation",
#     "fees"
#   ],
#   "OF030000": [
#     "fees",
#     "expedite"
#   ],
#   "OF040002": [
#     "sale",
#     "item",
#     "extension",
#     "transaction",
#     "certain",
#     "may",
#     "recurring",
#     "otherwise",
#     "original",
#     "interest",
#     "charges",
#     "jurisdictions",
#     "taxable",
#     "based",
#     "note",
#     "purchaser",
#     "charged",
#     "seller",
#     "exempt",
#     "financed",
#     "one-time",
#     "credit",
#     "fee",
#     "code",
#     "presumes"
#   ],
#   "OF040003": [
#     "sale",
#     "pay",
#     "item",
#     "transaction",
#     "failure",
#     "certain",
#     "recurring",
#     "may",
#     "otherwise",
#     "interest",
#     "charges",
#     "payment",
#     "jurisdictions",
#     "sales",
#     "taxable",
#     "re-billed",
#     "based",
#     "occurred",
#     "note",
#     "purchaser",
#     "charged",
#     "seller",
#     "exempt",
#     "financed",
#     "one-time",
#     "fee",
#     "late",
#     "usually",
#     "code",
#     "presumes"
#   ],
#   "OF040004": [
#     "sale",
#     "third",
#     "item",
#     "transaction",
#     "certain",
#     "may",
#     "otherwise",
#     "obrtained",
#     "interest",
#     "charges",
#     "jurisdictions",
#     "taxable",
#     "financing",
#     "note",
#     "purchaser",
#     "seller",
#     "exempt",
#     "financed",
#     "party",
#     "third-party",
#     "code",
#     "presumes"
#   ],
#   "OF040005": [
#     "credit",
#     "penalty",
#     "payment",
#     "late",
#     "charge",
#     "recurring",
#     "extension",
#     "associated",
#     "debt"
#   ],
#   "OF050100": [
#     "fee",
#     "batteries",
#     "charge",
#     "core",
#     "refundable",
#     "deposit"
#   ],
#   "OF050200": [
#     "fee",
#     "stand-alone",
#     "bulb",
#     "ballast",
#     "recycling",
#     "battery",
#     "non-refundable"
#   ],
#   "OF060001": [
#     "separately",
#     "credit",
#     "charged",
#     "charges",
#     "retailer",
#     "card",
#     "fees",
#     "customer",
#     "stated",
#     "passed",
#     "processing"
#   ],
#   "OF070001": [
#     "charged",
#     "marketplace",
#     "property",
#     "facilitated",
#     "commissions",
#     "sales",
#     "lodging",
#     "fees",
#     "facilitator",
#     "tangible",
#     "services",
#     "personal"
#   ],
#   "OH010000": [
#     "separately",
#     "charges",
#     "handling",
#     "shipping",
#     "identified"
#   ],
#   "OL010000": [
#     "property",
#     "commercial",
#     "use",
#     "boat",
#     "access",
#     "concessionaire",
#     "estate",
#     "license",
#     "mailbox",
#     "real",
#     "kitchen",
#     "facilities",
#     "restricted",
#     "launch"
#   ],
#   "OM010000": [
#     "made",
#     "donation",
#     "event",
#     "organization",
#     "place",
#     "charitable",
#     "amusement",
#     "admission",
#     "sporting",
#     "exchange",
#     "etc",
#     "voluntarily",
#     "monetary"
#   ],
#   "ON010000": [
#     "deposits",
#     "non-refundable"
#   ],
#   "ON010100": [
#     "right",
#     "nonrefundable",
#     "purchase",
#     "deposit"
#   ],
#   "ON030000": [
#     "used",
#     "user",
#     "associated",
#     "conducted",
#     "exempt",
#     "non-taxable",
#     "transaction",
#     "due",
#     "diligence",
#     "tax",
#     "this",
#     "code",
#     "default",
#     "system",
#     "determine",
#     "transactions"
#   ],
#   "OO028842": [
#     "occasional",
#     "sales"
#   ],
#   "OR040000": [
#     "fees",
#     "restocking"
#   ],
#   "OR070000": [
#     "name",
#     "charge",
#     "economic",
#     "value",
#     "?",
#     "one",
#     "payment",
#     "sales",
#     "measurable",
#     "based",
#     "fees",
#     "time",
#     "etc",
#     "copyright",
#     "periodic",
#     "paid",
#     "use",
#     "patent",
#     "royalty",
#     "trademark",
#     "someone"
#   ],
#   "OT010100": [
#     "prewritten",
#     "hotel",
#     "software",
#     "charges",
#     "expenses",
#     "related",
#     "etc",
#     "services",
#     "associated",
#     "-associated",
#     "seller",
#     "installation",
#     "seeking",
#     "rental",
#     "costs",
#     "car",
#     "air",
#     "implementation",
#     "reimbursed",
#     "travel"
#   ],
#   "OT010300": [
#     "property",
#     "tpp",
#     "hotel",
#     "tangible",
#     "and/or",
#     "expenses",
#     "charges",
#     "related",
#     "etc",
#     "services",
#     "associated",
#     "personal",
#     "seller",
#     "installation",
#     "seeking",
#     "rental",
#     "car",
#     "air",
#     "repair",
#     "reimbursed",
#     "travel"
#   ],
#   "OT010400": [
#     "personnel",
#     "rendered",
#     "professional",
#     "hotel",
#     "medical",
#     "expenses",
#     "charges",
#     "related",
#     "etc",
#     "services",
#     "associated",
#     "seller",
#     "rental",
#     "car",
#     "air",
#     "lawyers",
#     "accountants",
#     "reimbursed",
#     "travel"
#   ],
#   "OT010600": [
#     "paralegals",
#     "expenses",
#     "products",
#     "charges",
#     "related",
#     "serving",
#     "rendered",
#     "seller",
#     "process",
#     "lawyers",
#     "service",
#     "product",
#     "etc",
#     "legal",
#     "services",
#     "associated",
#     "reimbursed"
#   ],
#   "P0000000": [
#     "made",
#     "limit",
#     "property",
#     "number",
#     "deemed",
#     "user",
#     "consequently",
#     "tpp",
#     "taxability",
#     "nature",
#     "tangible",
#     "and/or",
#     "used",
#     "taxable",
#     "etc",
#     "non-taxable",
#     "local",
#     "statutes",
#     "tax",
#     "applicable",
#     "codes",
#     "system",
#     "associated",
#     "specific",
#     "personal",
#     "use",
#     "land",
#     "specifically",
#     "individual",
#     "buildings",
#     "unless",
#     "could",
#     "available",
#     "known",
#     "state",
#     "additionally",
#     "generally",
#     "products",
#     "items",
#     "want",
#     "default",
#     "real",
#     "code",
#     "presumption"
#   ],
#   "P000000H": [
#     "credit",
#     "ensure",
#     "proper",
#     "entry",
#     "calculation",
#     "amount",
#     "tpp",
#     "tax",
#     "negative",
#     "hostess",
#     "requires",
#     "purchased",
#     "credits"
#   ],
#   "P000100H": [
#     "taxable",
#     "entirely",
#     "tpp",
#     "credits",
#     "hostess",
#     "purchased"
#   ],
#   "P9999999": [
#     "unmapped",
#     "tpp",
#     "taxability",
#     "taxing",
#     "temporary",
#     "map",
#     "jurisdictions",
#     "taxable",
#     "used",
#     "tax",
#     "identified",
#     "system",
#     "specific",
#     "sku",
#     "known",
#     "product",
#     "purposes",
#     "this",
#     "products",
#     "default",
#     "code"
#   ],
#   "PA020000": [
#     "agricultural"
#   ],
#   "PA020003": [
#     "food",
#     "root",
#     "plants",
#     "plant",
#     "fertilizer",
#     "tone",
#     "producing"
#   ],
#   "PA020100": [
#     "equipment",
#     "agricultural-commercial",
#     "use-machinery"
#   ],
#   "PA020111": [
#     "annual",
#     "food",
#     "use",
#     "plants",
#     "producing",
#     "agricultural-commercial"
#   ],
#   "PA020113": [
#     "food",
#     "<",
#     "use",
#     "producing",
#     "agricultural-commercial",
#     "lbs",
#     "25",
#     "seeds"
#   ],
#   "PA020120": [
#     "includes",
#     "thermometers",
#     "products",
#     "hanging",
#     "use",
#     "sensors",
#     "agricultural",
#     "etc",
#     "scales",
#     "equipment",
#     "meters",
#     "monitoring",
#     "weather",
#     "livestock-commercial",
#     "testing",
#     "devices"
#   ],
#   "PA020121": [
#     "includes",
#     "solutions",
#     "products",
#     "use",
#     "foamers",
#     "systems",
#     "water",
#     "filtration",
#     "cleaning",
#     "agricultural",
#     "supplies",
#     "foggers",
#     "etc",
#     "line",
#     "equipment",
#     "cleaners",
#     "livestock-commercial",
#     "sprayers"
#   ],
#   "PA020122": [
#     "includes",
#     "electric",
#     "buckets",
#     "&",
#     "chutes",
#     "agricultural",
#     "etc",
#     "livestock",
#     "livestock-commercial",
#     "use",
#     "cooling",
#     "calf",
#     "products",
#     "headgates",
#     "waterers",
#     "feeders",
#     "prods",
#     "sorting",
#     "equipment",
#     "scales"
#   ],
#   "PA020123": [
#     "use",
#     "vaccine",
#     "agricultural",
#     "equipment",
#     "livestock-commercial"
#   ],
#   "PA020225": [
#     "includes",
#     "blowers",
#     "combs",
#     "dryers",
#     "show",
#     "fans",
#     "&",
#     "agricultural",
#     "sticks",
#     "livestock",
#     "livestock-commercial",
#     "use",
#     "blades",
#     "hair",
#     "halters",
#     "care",
#     "grooming",
#     "restraints",
#     "brushes",
#     "products",
#     "clippers",
#     "supplies",
#     "general"
#   ],
#   "PA020226": [
#     "applied",
#     "includes",
#     "products",
#     "use",
#     "supplies",
#     "agricultural",
#     "livestock",
#     "livestock-commercial",
#     "disinfectants",
#     "hygiene"
#   ],
#   "PA020227": [
#     "includes",
#     "animal",
#     "use",
#     "used",
#     "production",
#     "herbicides",
#     "agricultural",
#     "insecticides",
#     "pesticides",
#     "livestock",
#     "livestock-commercial"
#   ],
#   "PA020228": [
#     "includes",
#     "products",
#     "use",
#     "agricultural",
#     "tags",
#     "identification",
#     "id",
#     "livestock",
#     "brands",
#     "paint",
#     "tattoo",
#     "livestock-commercial"
#   ],
#   "PA020229": [
#     "includes",
#     "food",
#     "use",
#     "animals",
#     "agricultural",
#     "feed",
#     "livestock",
#     "livestock-commercial",
#     "farm"
#   ],
#   "PA020230": [
#     "use",
#     "supplies",
#     "agricultural",
#     "safety",
#     "livestock-commercial"
#   ],
#   "PA020231": [
#     "use",
#     "litter",
#     "agricultural",
#     "livestock-commercial"
#   ],
#   "PA020300": [
#     "use",
#     "agricultural",
#     "medicine",
#     "livestock-commercial"
#   ],
#   "PA020301": [
#     "includes",
#     "use",
#     "electrolytes",
#     "non-prescribed",
#     "additives",
#     "counter",
#     "agricultural",
#     "medicines",
#     "medicine",
#     "feed",
#     "supplements",
#     "livestock-commercial",
#     "probiotics",
#     "vitamins"
#   ],
#   "PA020302": [
#     "prescription",
#     "includes",
#     "inflammation",
#     "use",
#     "water",
#     "additives",
#     "antibiotics",
#     "agricultural",
#     "medicines",
#     "medicine",
#     "feed",
#     "pain",
#     "reproductive",
#     "&",
#     "antibiotic",
#     "livestock-commercial",
#     "dewormers"
#   ],
#   "PA020303": [
#     "includes",
#     "water",
#     "additives",
#     "antibiotics",
#     "&",
#     "sold",
#     "prescription",
#     "pain",
#     "agricultural",
#     "medicines",
#     "reproductive",
#     "antibiotic",
#     "livestock-commercial",
#     "veterinarians",
#     "use",
#     "feed",
#     "dewormers",
#     "inflammation",
#     "medicine"
#   ],
#   "PA020304": [
#     "veterinarians",
#     "includes",
#     "use",
#     "swine",
#     "cattle",
#     "poultry",
#     "agricultural",
#     "dairy",
#     "livestock",
#     "livestock-commercial",
#     "vaccines",
#     "sold"
#   ],
#   "PA020400": [
#     "use",
#     "supplies",
#     "agricultural",
#     "livestock-commercial",
#     "medical"
#   ],
#   "PA020401": [
#     "includes",
#     "products",
#     "use",
#     "effectiveness",
#     "vaccine",
#     "agricultural",
#     "help",
#     "delivery",
#     "livestock",
#     "livestock-commercial",
#     "stabilizers"
#   ],
#   "PA020402": [
#     "syringes",
#     "includes",
#     "use",
#     "related",
#     "vaccinators",
#     "kits",
#     "surgical",
#     "accessories",
#     "needles",
#     "agricultural",
#     "aspiration",
#     "equipment",
#     "&",
#     "livestock-commercial",
#     "injection"
#   ],
#   "PA020659": [
#     "food",
#     "vegetable",
#     "herb",
#     "producing",
#     "fruit",
#     "seeds"
#   ],
#   "PA020661": [
#     "vegetable",
#     "fruit",
#     "potatoes",
#     "onions",
#     "bulbs"
#   ],
#   "PA020662": [
#     "includes",
#     "woody",
#     "food",
#     "raspberry",
#     "pear",
#     "ornamental",
#     "plants",
#     "blueberry",
#     "producing",
#     "apple",
#     "trees",
#     "bush",
#     "vines"
#   ],
#   "PA020664": [
#     "food",
#     "plants",
#     "producing",
#     "insecticides",
#     "fungicides"
#   ],
#   "PA020665": [
#     "flower",
#     "excludes",
#     "bulbs",
#     "seeds"
#   ],
#   "PA020668": [
#     "herbicide",
#     "w/",
#     "plants",
#     "fertilizer",
#     "non-food",
#     "fertilizes",
#     "weeds",
#     "insecticide",
#     "producing",
#     "primarily",
#     "kills",
#     "dual-purpose"
#   ],
#   "PA020738": [
#     "food",
#     "animals",
#     "wild",
#     "farm",
#     "game"
#   ],
#   "PA021078": [
#     "food",
#     "vegetable",
#     "plants",
#     "herb",
#     "producing",
#     "fruit"
#   ],
#   "PA028802": [
#     "flowers",
#     "cut"
#   ]
# }

# %%
# Convert row to header and remove the row
df_csv = df_csv.rename(columns=df_csv.iloc[8])
df_csv = df_csv.loc[9:2000]
df_csv = df_csv.drop(columns = ['Version', 'Key', 'Column1', 'Synonym', 'Acronym'])
df_csv
# Out:
#        Segment                                      Segment Title  \
# 9     10000000  Live Plant and Animal Material and Accessories...
# 10    10000000  Live Plant and Animal Material and Accessories...
# 11    10000000  Live Plant and Animal Material and Accessories...
# 12    10000000  Live Plant and Animal Material and Accessories...
# 13    10000000  Live Plant and Animal Material and Accessories...
# ...        ...                                                ...
# 1996  10000000  Live Plant and Animal Material and Accessories...
# 1997  10000000  Live Plant and Animal Material and Accessories...
# 1998  10000000  Live Plant and Animal Material and Accessories...
# 1999  10000000  Live Plant and Animal Material and Accessories...
# 2000  10000000  Live Plant and Animal Material and Accessories...
#
#                                      Segment Definition    Family  \
# 9     This segment includes live, wild and domestica...       NaN
# 10    This segment includes live, wild and domestica...  10100000
# 11    This segment includes live, wild and domestica...  10100000
# 12    This segment includes live, wild and domestica...  10100000
# 13    This segment includes live, wild and domestica...  10100000
# ...                                                 ...       ...
# 1996  This segment includes live, wild and domestica...  10210000
# 1997  This segment includes live, wild and domestica...  10210000
# 1998  This segment includes live, wild and domestica...  10210000
# 1999  This segment includes live, wild and domestica...  10210000
# 2000  This segment includes live, wild and domestica...  10210000
#
#                                            Family Title  \
# 9                                                   NaN
# 10                                         Live animals
# 11                                         Live animals
# 12                                         Live animals
# 13                                         Live animals
# ...                                                 ...
# 1996  Live plants of high species or variety count f...
# 1997  Live plants of high species or variety count f...
# 1998  Live plants of high species or variety count f...
# 1999  Live plants of high species or variety count f...
# 2000  Live plants of high species or variety count f...
#
#                                       Family Definition     Class  \
# 9                                                   NaN       NaN
# 10                                                  NaN       NaN
# 11                                                  NaN  10101500
# 12                                                  NaN  10101500
# 13                                                  NaN  10101500
# ...                                                 ...       ...
# 1996  Live plants including the root ball of flower ...  10216000
# 1997  Live plants including the root ball of flower ...  10216000
# 1998  Live plants including the root ball of flower ...  10216000
# 1999  Live plants including the root ball of flower ...  10216000
# 2000  Live plants including the root ball of flower ...  10216000
#
#                   Class Title  \
# 9                         NaN
# 10                        NaN
# 11                  Livestock
# 12                  Livestock
# 13                  Livestock
# ...                       ...
# 1996  Live ornamental peppers
# 1997  Live ornamental peppers
# 1998  Live ornamental peppers
# 1999  Live ornamental peppers
# 2000  Live ornamental peppers
#
#                                        Class Definition Commodity  \
# 9                                                   NaN       NaN
# 10                                                  NaN       NaN
# 11                                                  NaN       NaN
# 12                                                  NaN  10101501
# 13                                                  NaN  10101502
# ...                                                 ...       ...
# 1996  Live plants including the root ball of ornamen...       NaN
# 1997  Live plants including the root ball of ornamen...  10216001
# 1998  Live plants including the root ball of ornamen...  10216002
# 1999  Live plants including the root ball of ornamen...  10216003
# 2000  Live plants including the root ball of ornamen...  10216004
#
#                     Commodity Title  \
# 9                               NaN
# 10                              NaN
# 11                              NaN
# 12                             Cats
# 13                             Dogs
# ...                             ...
# 1996                            NaN
# 1997   Live ornamental chili pepper
# 1998   Live ornamental mixed pepper
# 1999  Live ornamental orange pepper
# 2000     Live ornamental red pepper
#
#                                              Definition
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# ...                                                 ...
# 1996                                                NaN
# 1997  Live plant including the root ball of the orna...
# 1998  Live plant including the root ball of the orna...
# 1999  Live plant including the root ball of the orna...
# 2000  Live plant including the root ball of the orna...
#
# [1992 rows x 12 columns]

# %%
column_name = 'Segment Title'
column_name_2 = 'Segment Definition'
column_name_3 = 'Family Title'
column_name_4 = 'Family Definition'
column_name_5 = 'Class Title'
column_name_6 = 'Class Definition'
column_name_7 = 'Commodity Title'
column_name_8 = 'Definition'
createParsedColumns(df_csv, column_name, column_name_2, 9, 'segment_parsed')
createParsedColumns(df_csv, column_name_3, column_name_4, 9, 'family_parsed')
createParsedColumns(df_csv, column_name_5, column_name_6, 9, 'class_parsed')
createParsedColumns(df_csv, column_name_7, column_name_8, 9, 'commodity_parsed')
df_csv
# Out:
#        Segment                                    Segment Title  \
# 9     10000000  live,plant,animal,material,accessories,supplies
# 10    10000000  live,plant,animal,material,accessories,supplies
# 11    10000000  live,plant,animal,material,accessories,supplies
# 12    10000000  live,plant,animal,material,accessories,supplies
# 13    10000000  live,plant,animal,material,accessories,supplies
# ...        ...                                              ...
# 1996  10000000  live,plant,animal,material,accessories,supplies
# 1997  10000000  live,plant,animal,material,accessories,supplies
# 1998  10000000  live,plant,animal,material,accessories,supplies
# 1999  10000000  live,plant,animal,material,accessories,supplies
# 2000  10000000  live,plant,animal,material,accessories,supplies
#
#                                      Segment Definition    Family  \
# 9     this,segment,includes,live,wild,domesticated,s...       NaN
# 10    this,segment,includes,live,wild,domesticated,s...  10100000
# 11    this,segment,includes,live,wild,domesticated,s...  10100000
# 12    this,segment,includes,live,wild,domesticated,s...  10100000
# 13    this,segment,includes,live,wild,domesticated,s...  10100000
# ...                                                 ...       ...
# 1996  this,segment,includes,live,wild,domesticated,s...  10210000
# 1997  this,segment,includes,live,wild,domesticated,s...  10210000
# 1998  this,segment,includes,live,wild,domesticated,s...  10210000
# 1999  this,segment,includes,live,wild,domesticated,s...  10210000
# 2000  this,segment,includes,live,wild,domesticated,s...  10210000
#
#                                         Family Title  \
# 9
# 10                                      live,animals
# 11                                      live,animals
# 12                                      live,animals
# 13                                      live,animals
# ...                                              ...
# 1996  live,plants,high,species,variety,count,flowers
# 1997  live,plants,high,species,variety,count,flowers
# 1998  live,plants,high,species,variety,count,flowers
# 1999  live,plants,high,species,variety,count,flowers
# 2000  live,plants,high,species,variety,count,flowers
#
#                                       Family Definition     Class  \
# 9                                                             NaN
# 10                                                            NaN
# 11                                                       10101500
# 12                                                       10101500
# 13                                                       10101500
# ...                                                 ...       ...
# 1996  live,plants,including,root,ball,flower,types,5...  10216000
# 1997  live,plants,including,root,ball,flower,types,5...  10216000
# 1998  live,plants,including,root,ball,flower,types,5...  10216000
# 1999  live,plants,including,root,ball,flower,types,5...  10216000
# 2000  live,plants,including,root,ball,flower,types,5...  10216000
#
#                   Class Title  \
# 9
# 10
# 11                  livestock
# 12                  livestock
# 13                  livestock
# ...                       ...
# 1996  live,ornamental,peppers
# 1997  live,ornamental,peppers
# 1998  live,ornamental,peppers
# 1999  live,ornamental,peppers
# 2000  live,ornamental,peppers
#
#                                        Class Definition Commodity  \
# 9                                                             NaN
# 10                                                            NaN
# 11                                                            NaN
# 12                                                       10101501
# 13                                                       10101502
# ...                                                 ...       ...
# 1996  live,plants,including,root,ball,ornamental,pep...       NaN
# 1997  live,plants,including,root,ball,ornamental,pep...  10216001
# 1998  live,plants,including,root,ball,ornamental,pep...  10216002
# 1999  live,plants,including,root,ball,ornamental,pep...  10216003
# 2000  live,plants,including,root,ball,ornamental,pep...  10216004
#
#                     Commodity Title  \
# 9
# 10
# 11
# 12                             cats
# 13                             dogs
# ...                             ...
# 1996
# 1997   live,ornamental,chili,pepper
# 1998   live,ornamental,mixed,pepper
# 1999  live,ornamental,orange,pepper
# 2000     live,ornamental,red,pepper
#
#                                              Definition  \
# 9
# 10
# 11
# 12
# 13
# ...                                                 ...
# 1996
# 1997  live,plant,including,root,ball,ornamental,chil...
# 1998  live,plant,including,root,ball,ornamental,mixe...
# 1999  live,plant,including,root,ball,ornamental,oran...
# 2000  live,plant,including,root,ball,ornamental,red,...
#
#                                          segment_parsed  \
# 9     [includes, also, feeding, animal, plants, plan...
# 10    [includes, also, feeding, animal, plants, plan...
# 11    [includes, also, feeding, animal, plants, plan...
# 12    [includes, also, feeding, animal, plants, plan...
# 13    [includes, also, feeding, animal, plants, plan...
# ...                                                 ...
# 1996  [includes, also, feeding, animal, plants, plan...
# 1997  [includes, also, feeding, animal, plants, plan...
# 1998  [includes, also, feeding, animal, plants, plan...
# 1999  [includes, also, feeding, animal, plants, plan...
# 2000  [includes, also, feeding, animal, plants, plan...
#
#                                           family_parsed  \
# 9                                                    []
# 10                                      [animals, live]
# 11                                      [animals, live]
# 12                                      [animals, live]
# 13                                      [animals, live]
# ...                                                 ...
# 1996  [including, species, flowers, ball, root, plan...
# 1997  [including, species, flowers, ball, root, plan...
# 1998  [including, species, flowers, ball, root, plan...
# 1999  [including, species, flowers, ball, root, plan...
# 2000  [including, species, flowers, ball, root, plan...
#
#                                            class_parsed  \
# 9                                                    []
# 10                                                   []
# 11                                          [livestock]
# 12                                          [livestock]
# 13                                          [livestock]
# ...                                                 ...
# 1996  [ball, flowers, peppers, root, ornamental, pla...
# 1997  [ball, flowers, peppers, root, ornamental, pla...
# 1998  [ball, flowers, peppers, root, ornamental, pla...
# 1999  [ball, flowers, peppers, root, ornamental, pla...
# 2000  [ball, flowers, peppers, root, ornamental, pla...
#
#                                        commodity_parsed
# 9                                                    []
# 10                                                   []
# 11                                                   []
# 12                                               [cats]
# 13                                               [dogs]
# ...                                                 ...
# 1996                                                 []
# 1997  [including, ball, flowers, root, ornamental, c...
# 1998  [including, ball, flowers, mixed, root, orname...
# 1999  [including, ball, flowers, root, ornamental, p...
# 2000  [including, ball, flowers, root, ornamental, p...
#
# [1992 rows x 16 columns]

# %%
unspsc_tc_table_lvl_1 = {}
unspsc_tc_table_lvl_2 = {}
unspsc_tc_table_lvl_3 = {}
unspsc_tc_table_lvl_4 = {}

seg_new_name = 'segment_parsed'
fam_new_name = 'family_parsed'
class_new_name = 'class_parsed'
com_new_name = 'commodity_parsed'

for index, com_code in enumerate(df_csv['Commodity'], 9):
    # if tax_code = NaN
#     if isinstance(seg_code, float):
#         prefix = df_csv["Segment"].loc[index + 1]
#         level_1 = prefix[0:2]
#         level_2 = prefix[2:4]
#         level_3 = "0000"
#         df_xlsx["AvaTax System Tax Code"].loc[index] = prefix[0:4]+"0000"
#     else:
    
    if isinstance(com_code, float):
        continue
    else:
        level_1 = com_code[0:2] 
        level_2 = com_code[0:4]
        level_3 = com_code[0:6]
        level_4 = com_code[0:8]


    if level_1 not in unspsc_tc_table_lvl_1:
        unspsc_tc_table_lvl_1[level_1] = df_csv[seg_new_name].loc[index]

    if level_2 not in unspsc_tc_table_lvl_2:
        unspsc_tc_table_lvl_2[level_2] = df_csv[fam_new_name].loc[index]

    if level_3 not in unspsc_tc_table_lvl_3:
        unspsc_tc_table_lvl_3[level_3] = df_csv[class_new_name].loc[index]     

    if level_4 not in unspsc_tc_table_lvl_3:
        unspsc_tc_table_lvl_3[level_3] = df_csv[com_new_name].loc[index]

print(json.dumps(unspsc_tc_table_lvl_1, sort_keys=True, indent=2))
print(json.dumps(unspsc_tc_table_lvl_2, sort_keys=True, indent=2))
print(json.dumps(unspsc_tc_table_lvl_3, sort_keys=True, indent=2))
print(json.dumps(unspsc_tc_table_lvl_4, sort_keys=True, indent=2))
# Out:
# {
#   "10000000": [
#     "includes",
#     "also",
#     "feeding",
#     "animal",
#     "plants",
#     "plant",
#     "live",
#     "segment",
#     "used",
#     "domesticated",
#     "materials",
#     "wild",
#     "containment",
#     "this",
#     "care",
#     "animals",
#     "accessories",
#     "material",
#     "supplies",
#     "equipment",
#     "seeds"
#   ]
# }
# {
#   "10100000": [
#     "animals",
#     "live"
#   ],
#   "10110000": [
#     "pet",
#     "domestic",
#     "products"
#   ],
#   "10120000": [
#     "feed",
#     "animal"
#   ],
#   "10130000": [
#     "habitats",
#     "animal",
#     "containment"
#   ],
#   "10140000": [
#     "saddlery",
#     "goods",
#     "harness"
#   ],
#   "10150000": [
#     "seedlings",
#     "cuttings",
#     "bulbs",
#     "seeds"
#   ],
#   "10160000": [
#     "floriculture",
#     "silviculture",
#     "products"
#   ],
#   "10170000": [
#     "plant",
#     "herbicides",
#     "fertilizers",
#     "nutrients"
#   ],
#   "10190000": [
#     "control",
#     "products",
#     "pest"
#   ],
#   "10200000": [
#     "rose",
#     "roots",
#     "bushes",
#     "roses",
#     "including",
#     "live"
#   ],
#   "10210000": [
#     "including",
#     "species",
#     "flowers",
#     "ball",
#     "root",
#     "plants",
#     "registered",
#     "unspsc",
#     "flower",
#     "types",
#     "varieties",
#     "count",
#     "5",
#     "variety",
#     "high",
#     "live"
#   ]
# }
# {
#   "10101500": [
#     "weight",
#     "their",
#     "animal",
#     "pack",
#     "kilometers",
#     "used",
#     "32",
#     "23",
#     "day",
#     "indians",
#     "andes",
#     "domesticated",
#     "centuries",
#     "the",
#     "able",
#     "kilograms",
#     "inhabitants",
#     "wild",
#     "relatives",
#     "llama",
#     "strong",
#     "support",
#     "vicunas",
#     "animals",
#     "guanacos",
#     "34",
#     "single",
#     "travel"
#   ],
#   "10101600": [
#     "guinea",
#     "phasianidae",
#     "although",
#     "family",
#     "fowl",
#     "guineafowl",
#     "type",
#     "native",
#     "authorities",
#     "africa",
#     "order",
#     "galliformes",
#     "include",
#     "subfamily",
#     "numidinae",
#     "bird",
#     "live"
#   ],
#   "10101700": [
#     "america",
#     "raised",
#     "native",
#     "months",
#     "flesh",
#     "size",
#     "orinoco",
#     "markets",
#     "reproduction",
#     "it",
#     "live",
#     "firm",
#     "scientifically",
#     "amazon",
#     "farms",
#     "performed",
#     "important",
#     "weighs",
#     "within",
#     "really",
#     "artificially",
#     "tasty",
#     "colossoma",
#     "three",
#     "reaches",
#     "the",
#     "river",
#     "mention",
#     "cycle",
#     "grams",
#     "brasilian",
#     "known",
#     "matures",
#     "350",
#     "macropomum",
#     "rapidly",
#     "south",
#     "commercial",
#     "lot",
#     "fish",
#     "fast",
#     "four",
#     "hormonal",
#     "300",
#     "colombian",
#     "tambaqui",
#     "injection",
#     "basins",
#     "demand"
#   ],
#   "10101800": [
#     "name",
#     "royal",
#     "green",
#     "gastronomic",
#     "value",
#     "live",
#     "elephas",
#     "rock",
#     "important",
#     "scientific",
#     "american",
#     "the",
#     "palinurus",
#     "sea",
#     "crustacean",
#     "higher",
#     "red",
#     "variety",
#     "portugals",
#     "lobster",
#     "varieties",
#     "mauritanias",
#     "spiny",
#     "pink"
#   ],
#   "10101900": [
#     "their",
#     "larvae",
#     "damage",
#     "also",
#     "entry",
#     "plants",
#     "plant",
#     "leaving",
#     "stem",
#     "many",
#     "insects",
#     "diatraea",
#     "live",
#     "countries",
#     "one",
#     "substances",
#     "transport",
#     "species",
#     "argentina",
#     "stems",
#     "agricultural",
#     "break",
#     "borers",
#     "health",
#     "sugarcane",
#     "the",
#     "saccharalis",
#     "cultivated",
#     "known",
#     "feed",
#     "insect",
#     "producing",
#     "fungi",
#     "holes",
#     "lepidopter",
#     "states",
#     "prevent",
#     "leaves",
#     "whose",
#     "way",
#     "destructive",
#     "borer",
#     "nutrients",
#     "they",
#     "dangerous",
#     "toxins",
#     "united",
#     "human"
#   ],
#   "10102000": [
#     "seal",
#     "pinniped",
#     "commonly",
#     "member",
#     "semi-aquatic",
#     "mammals",
#     "called",
#     "seals",
#     "group",
#     "many",
#     "diverse",
#     "live",
#     "marine"
#   ],
#   "10102100": [
#     "eggs",
#     "fertilized",
#     "duck",
#     "grow-out",
#     "hatching"
#   ],
#   "10111300": [
#     "container",
#     "outdoor",
#     "whereas",
#     "water",
#     "holds",
#     "baths",
#     "may",
#     "bird",
#     "basin",
#     "attached",
#     "pool",
#     "indoor",
#     "drink",
#     "birds",
#     "shape",
#     "box-shaped",
#     "bathe",
#     "bath",
#     "shallow",
#     "cage",
#     "usually",
#     "clips",
#     "allow"
#   ],
#   "10121500": [
#     "forage",
#     "rumen",
#     "flora",
#     "correct",
#     "increasing",
#     "thus",
#     "helps",
#     "digestion",
#     "deficiencies",
#     "population",
#     "salt",
#     "fed",
#     "livestock",
#     "form",
#     "designed",
#     "it",
#     "microbial"
#   ],
#   "10121600": [
#     "food",
#     "poultry"
#   ],
#   "10121700": [
#     "food",
#     "flakes",
#     "fish"
#   ],
#   "10121800": [
#     "treats",
#     "dogs",
#     "snacks",
#     "cats"
#   ],
#   "10121900": [
#     "pelletized",
#     "rodents",
#     "food"
#   ],
#   "10122000": [
#     "food",
#     "live",
#     "reptiles"
#   ],
#   "10122100": [
#     "rabbit",
#     "food"
#   ],
#   "10131500": [
#     "pet",
#     "beds"
#   ],
#   "10131600": [
#     "cage",
#     "cages",
#     "transport",
#     "animal"
#   ],
#   "10131700": [
#     "aquariums"
#   ],
#   "10141500": [
#     "saddle",
#     "horse",
#     "pad",
#     "placed",
#     "riding"
#   ],
#   "10141600": [
#     "dog",
#     "animal",
#     "control",
#     "catching",
#     "equipment",
#     "pole"
#   ],
#   "10151500": [
#     "warm",
#     "name",
#     "habones",
#     "an",
#     "temperate",
#     "herbaceous",
#     "legume",
#     "lunatus",
#     "edible",
#     "it",
#     "countries",
#     "annual",
#     "species",
#     "carob",
#     "phaseolus",
#     "lima",
#     "scientific",
#     "various",
#     "family",
#     "bean",
#     "guaracaro",
#     "seed",
#     "grown",
#     "seedlings",
#     "pallar"
#   ],
#   "10151600": [
#     "sugar",
#     "water",
#     "large",
#     "giant",
#     "sorghum",
#     "6",
#     "stem",
#     "solid",
#     "2-5",
#     "it",
#     "related",
#     "cm",
#     "diameter",
#     "grass",
#     "sugarcane",
#     "amount",
#     "cane",
#     "feet",
#     "5",
#     "grow",
#     "requires",
#     "tropical",
#     "seed",
#     "maize",
#     "cutting",
#     "high"
#   ],
#   "10151700": [
#     "america",
#     "species",
#     "family",
#     "reed",
#     "herbaceous",
#     "plant",
#     "native",
#     "seed",
#     "grasses",
#     "cutting",
#     "belonging",
#     "gynerium",
#     "it",
#     "sagittatum"
#   ],
#   "10151800": [
#     "plants",
#     "seed",
#     "seedlings",
#     "dill",
#     "seeds"
#   ],
#   "10151900": [
#     "america",
#     "also",
#     "masiqu\u00eda",
#     "plant",
#     "cadillo",
#     "it",
#     "comes",
#     "asteraceae",
#     "1",
#     "distribution",
#     "the",
#     "family",
#     "cosmopolitan",
#     "known",
#     "cuttings",
#     "south",
#     "chipaca",
#     "macraea",
#     "seed",
#     "bidens",
#     "pilosa",
#     "seeds"
#   ],
#   "10152000": [
#     "12",
#     "name",
#     "ramoncillo",
#     "meliaceae",
#     "common",
#     "siguaraya",
#     "meters",
#     "bitter",
#     "palo",
#     "family",
#     "caribbean",
#     "tree",
#     "grow",
#     "belongs",
#     "cedrillo",
#     "seed",
#     "seedling",
#     "cutting",
#     "distributed"
#   ],
#   "10152100": [
#     "cake",
#     "neem",
#     "oil"
#   ],
#   "10152200": [
#     "flax",
#     "seedlings",
#     "seeds"
#   ],
#   "10152300": [
#     "soya",
#     "seedlings",
#     "seeds"
#   ],
#   "10152400": [
#     "radish",
#     "seedlings",
#     "seeds"
#   ],
#   "10161500": [
#     "lanka",
#     "species",
#     "family",
#     "cinnamon",
#     "used",
#     "sri",
#     "rosaceae",
#     "powder",
#     "10",
#     "known",
#     "its",
#     "tree",
#     "meters",
#     "measure",
#     "high",
#     "cinnamus",
#     "15"
#   ],
#   "10161600": [
#     "temperate",
#     "family",
#     "used",
#     "japan",
#     "native",
#     "ornamental",
#     "plant",
#     "plants",
#     "evergreen",
#     "foliage",
#     "regions",
#     "grown",
#     "shade",
#     "asparagaceae",
#     "garden",
#     "serpentine",
#     "they"
#   ],
#   "10161800": [
#     "made",
#     "stems",
#     "roll-shaped",
#     "grass",
#     "reticulated",
#     "nets"
#   ],
#   "10161900": [
#     "flower",
#     "dried",
#     "petals"
#   ],
#   "10171500": [
#     "urea",
#     "rich",
#     "organic",
#     "fertilizer",
#     "plant",
#     "fertilisers",
#     "nutrient",
#     "soil",
#     "nitrogen",
#     "supplements"
#   ],
#   "10171600": [
#     "pruning",
#     "wound",
#     "used",
#     "preparation",
#     "manage",
#     "dressing",
#     "injured",
#     "tree",
#     "trees",
#     "treatment"
#   ],
#   "10171700": [
#     "herbicide",
#     "used",
#     "activity",
#     "selective",
#     "control",
#     "grass",
#     "weeds",
#     "short",
#     "propanil",
#     "broad-leaved",
#     "contact",
#     "duration"
#   ],
#   "10171800": [
#     "appropriate",
#     "conditioner",
#     "used",
#     "plant",
#     "product",
#     "growth",
#     "improve",
#     "soil",
#     "inorganic",
#     "properties"
#   ],
#   "10191500": [
#     "also",
#     "typically",
#     "plant",
#     "involves",
#     "relies",
#     "predation",
#     "insects",
#     "it",
#     "controlling",
#     "mites",
#     "control",
#     "pests",
#     "herbivory",
#     "management",
#     "non-chemical",
#     "using",
#     "diseases",
#     "method",
#     "weeds",
#     "organisms",
#     "active",
#     "natural",
#     "pest",
#     "role",
#     "parasitism",
#     "solution",
#     "biological",
#     "mechanisms",
#     "human"
#   ],
#   "10191700": [
#     "sound",
#     "deter",
#     "pest",
#     "repeller",
#     "high-frequency",
#     "ultrasonic",
#     "pests",
#     "repel",
#     "employing",
#     "device"
#   ],
#   "10201500": [
#     "two",
#     "rose",
#     "including",
#     "roots",
#     "variety",
#     "bush",
#     "faces",
#     "live"
#   ],
#   "10201600": [
#     "terracotta",
#     "rose",
#     "roots",
#     "variety",
#     "bush",
#     "including",
#     "live"
#   ],
#   "10201700": [
#     "variety",
#     "rose",
#     "roots",
#     "virginia",
#     "bush",
#     "including",
#     "live"
#   ],
#   "10201800": [
#     "zazu",
#     "rose",
#     "including",
#     "roots",
#     "variety",
#     "bush",
#     "live"
#   ],
#   "10201900": [
#     "rose",
#     "roots",
#     "whisper",
#     "variety",
#     "bush",
#     "including",
#     "live"
#   ],
#   "10202000": [
#     "rose",
#     "verdi",
#     "roots",
#     "variety",
#     "bush",
#     "including",
#     "live"
#   ],
#   "10202100": [
#     "rose",
#     "roots",
#     "yabadabadoo",
#     "variety",
#     "bush",
#     "including",
#     "live"
#   ],
#   "10202200": [
#     "rose",
#     "roots",
#     "wanda",
#     "variety",
#     "bush",
#     "including",
#     "live"
#   ],
#   "10202300": [
#     "piaget",
#     "including",
#     "rose",
#     "roots",
#     "variety",
#     "bush",
#     "live",
#     "yves"
#   ],
#   "10202400": [
#     "rose",
#     "roots",
#     "xcite",
#     "variety",
#     "bush",
#     "including",
#     "live"
#   ],
#   "10202500": [
#     "yellow",
#     "including",
#     "rose",
#     "roots",
#     "sweetheart",
#     "variety",
#     "bush",
#     "live"
#   ],
#   "10202600": [
#     "including",
#     "rose",
#     "bush",
#     "roots",
#     "white",
#     "variety",
#     "dove",
#     "live"
#   ],
#   "10202700": [
#     "yellow",
#     "including",
#     "rose",
#     "roots",
#     "timeless",
#     "variety",
#     "bush",
#     "live"
#   ],
#   "10202800": [
#     "yellow",
#     "follies",
#     "rose",
#     "spray",
#     "including",
#     "roots",
#     "variety",
#     "bush",
#     "live"
#   ],
#   "10211500": [
#     "anthuriums",
#     "including",
#     "ball",
#     "anthurium",
#     "root",
#     "plant",
#     "wild",
#     "variety",
#     "thing",
#     "live"
#   ],
#   "10211600": [
#     "everest",
#     "including",
#     "ball",
#     "alliums",
#     "root",
#     "plant",
#     "allium",
#     "white",
#     "variety",
#     "mount",
#     "live"
#   ],
#   "10211700": [
#     "ball",
#     "root",
#     "plant",
#     "alstroemerias",
#     "alstroemeria",
#     "white",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10211800": [
#     "including",
#     "ball",
#     "amaranthus",
#     "root",
#     "upright",
#     "plant",
#     "red",
#     "variety",
#     "live"
#   ],
#   "10211900": [
#     "night",
#     "including",
#     "ball",
#     "root",
#     "amaryllises",
#     "plant",
#     "tinto",
#     "variety",
#     "live",
#     "amaryllis"
#   ],
#   "10212000": [
#     "ball",
#     "root",
#     "plant",
#     "white",
#     "variety",
#     "anemone",
#     "including",
#     "live"
#   ],
#   "10212100": [
#     "ball",
#     "root",
#     "plant",
#     "asclepias",
#     "asclepia",
#     "white",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10212200": [
#     "including",
#     "ball",
#     "root",
#     "spider",
#     "plant",
#     "asters",
#     "variety",
#     "aster",
#     "live"
#   ],
#   "10212300": [
#     "variety",
#     "including",
#     "ball",
#     "root",
#     "plant",
#     "squarrosa",
#     "berzelia",
#     "lanuginosa",
#     "live",
#     "lanuginosas"
#   ],
#   "10212400": [
#     "ball",
#     "bouvardias",
#     "root",
#     "plant",
#     "bouvardia",
#     "white",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10212500": [
#     "including",
#     "ball",
#     "brodiaeas",
#     "root",
#     "plant",
#     "starlight",
#     "variety",
#     "brodiaea",
#     "live"
#   ],
#   "10212600": [
#     "calla",
#     "including",
#     "ball",
#     "root",
#     "callas",
#     "plant",
#     "large",
#     "white",
#     "variety",
#     "live"
#   ],
#   "10212800": [
#     "yellow",
#     "including",
#     "ball",
#     "celosia",
#     "root",
#     "wheat",
#     "plant",
#     "celosias",
#     "variety",
#     "live"
#   ],
#   "10212900": [
#     "yellow",
#     "including",
#     "ball",
#     "root",
#     "daffodil",
#     "plant",
#     "daffodils",
#     "carlton",
#     "variety",
#     "live"
#   ],
#   "10213000": [
#     "yellow",
#     "dahlia",
#     "ball",
#     "root",
#     "plant",
#     "dahlias",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10213100": [
#     "volkerfrieden",
#     "ball",
#     "delphiniums",
#     "root",
#     "plant",
#     "delphinium",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10213200": [
#     "including",
#     "ball",
#     "root",
#     "plant",
#     "rosie",
#     "dianthuses",
#     "variety",
#     "dianthus",
#     "live",
#     "pink"
#   ],
#   "10213300": [
#     "yellow",
#     "eremuruses",
#     "ball",
#     "root",
#     "plant",
#     "eremurus",
#     "including",
#     "live"
#   ],
#   "10213400": [
#     "including",
#     "whales",
#     "ball",
#     "root",
#     "prince",
#     "plant",
#     "ericas",
#     "variety",
#     "erica",
#     "live"
#   ],
#   "10213500": [
#     "yellow",
#     "including",
#     "ball",
#     "root",
#     "plant",
#     "spurge",
#     "euphorbias",
#     "euphorbia",
#     "variety",
#     "live"
#   ],
#   "10213600": [
#     "yellow",
#     "ball",
#     "root",
#     "plant",
#     "freesias",
#     "freesia",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10213700": [
#     "including",
#     "ball",
#     "vulpis",
#     "root",
#     "uva",
#     "plant",
#     "uva-vulpis",
#     "frittilaria",
#     "frittilarias",
#     "live"
#   ],
#   "10213800": [
#     "yellow",
#     "genistas",
#     "genista",
#     "ball",
#     "root",
#     "plant",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10213900": [
#     "yellow",
#     "gerbera",
#     "ball",
#     "gerberas",
#     "root",
#     "plant",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10214000": [
#     "ball",
#     "flowers",
#     "root",
#     "plant",
#     "ginger",
#     "torch",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10214100": [
#     "yellow",
#     "ball",
#     "root",
#     "plant",
#     "gladioluses",
#     "gladiolus",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10214200": [
#     "godetia",
#     "ball",
#     "root",
#     "plant",
#     "godetias",
#     "white",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10214300": [
#     "variegata",
#     "including",
#     "guzmania",
#     "ball",
#     "root",
#     "plant",
#     "guzmanias",
#     "variety",
#     "live"
#   ],
#   "10214400": [
#     "including",
#     "ball",
#     "perfecta",
#     "root",
#     "plant",
#     "gypsophilias",
#     "gypsophilia",
#     "variety",
#     "live"
#   ],
#   "10214500": [
#     "ball",
#     "root",
#     "plant",
#     "heather",
#     "heathers",
#     "white",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10214600": [
#     "including",
#     "ball",
#     "root",
#     "plant",
#     "heliconia",
#     "heliconias",
#     "variety",
#     "live",
#     "wagneriana"
#   ],
#   "10214700": [
#     "yellow",
#     "ball",
#     "root",
#     "hyacinth",
#     "plant",
#     "hyacinths",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10214800": [
#     "ball",
#     "root",
#     "hydrangeas",
#     "plant",
#     "hydrangea",
#     "white",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10214900": [
#     "including",
#     "ball",
#     "root",
#     "plant",
#     "iris",
#     "telstar",
#     "irises",
#     "variety",
#     "live"
#   ],
#   "10215000": [
#     "yellow",
#     "including",
#     "ball",
#     "flowers",
#     "root",
#     "plant",
#     "paw",
#     "kangaroo",
#     "live"
#   ],
#   "10215100": [
#     "ball",
#     "root",
#     "larkspurs",
#     "plant",
#     "white",
#     "variety",
#     "larkspur",
#     "including",
#     "live"
#   ],
#   "10215200": [
#     "ball",
#     "root",
#     "plant",
#     "lepto",
#     "white",
#     "variety",
#     "leptos",
#     "including",
#     "live"
#   ],
#   "10215300": [
#     "including",
#     "ball",
#     "lilac",
#     "root",
#     "plant",
#     "wild",
#     "lilacs",
#     "white",
#     "variety",
#     "live"
#   ],
#   "10215400": [
#     "ball",
#     "root",
#     "water",
#     "plant",
#     "lily",
#     "lilies",
#     "including",
#     "live"
#   ],
#   "10215500": [
#     "limonium",
#     "ball",
#     "root",
#     "plant",
#     "sinensis",
#     "limoniums",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10215600": [
#     "purple",
#     "including",
#     "ball",
#     "root",
#     "lisianthus",
#     "plant",
#     "lisianthuses",
#     "white",
#     "variety",
#     "edge",
#     "live"
#   ],
#   "10215700": [
#     "including",
#     "ball",
#     "muscarises",
#     "valerie",
#     "root",
#     "muscari",
#     "plant",
#     "finn",
#     "variety",
#     "live"
#   ],
#   "10215800": [
#     "ball",
#     "thalia",
#     "root",
#     "plant",
#     "narcissus",
#     "variety",
#     "including",
#     "live"
#   ],
#   "10216000": [
#     "including",
#     "ball",
#     "flowers",
#     "root",
#     "ornamental",
#     "plant",
#     "red",
#     "pepper",
#     "live"
#   ]
# }
# {}

# %%
from collections import defaultdict

factory = lambda: defaultdict(factory)

unspc_segments = defaultdict(factory)
unspc_family = defaultdict(factory)
unspc_class = defaultdict(factory)
unspc_commodity = defaultdict(factory)

unspc_family_full = defaultdict(factory)
unspc_class_full = defaultdict(factory)
unspc_commodity_full = defaultdict(factory)

for index in range(9, len(df_csv.index)):
    if not pd.isna(df_csv['Commodity'].iloc[index]):
        seg_key = str(df_csv['Commodity'].iloc[index])[:2]
        fam_key = str(df_csv['Commodity'].iloc[index])[2:4]
        class_key = str(df_csv['Commodity'].iloc[index])[4:6]
        com_key = str(df_csv['Commodity'].iloc[index])[6:8]
    elif not pd.isna(df_csv['Class'].iloc[index]):
        seg_key = str(df_csv['Class'].iloc[index])[:2]
        fam_key = str(df_csv['Class'].iloc[index])[2:4]
        class_key = str(df_csv['Class'].iloc[index])[4:6]
        com_key = ""
    elif not pd.isna(df_csv['Family'].iloc[index]):
        seg_key = str(df_csv['Family'].iloc[index])[:2]
        fam_key = str(df_csv['Family'].iloc[index])[2:4]
        class_key = ""
        com_key = ""
    elif not pd.isna(df_csv['Segment'].iloc[index]):
        seg_key = str(df_csv['Segment'].iloc[index])[:2]
        fam_key = ""
        class_key = ""
        com_key = ""
    else:
        seg_key = ""
        fam_key = ""
        class_key = ""
        com_key = ""

    # segments hash map
    if seg_key:
        if seg_key not in unspc_segments:
            unspc_segments[seg_key] = df_csv['segment_parsed'].iloc[index]

    # family hash map
    if seg_key and fam_key:
        if seg_key not in unspc_family:
            unspc_family[seg_key][fam_key] = df_csv['family_parsed'].iloc[index]
        elif fam_key not in unspc_family[seg_key]:
            unspc_family[seg_key][fam_key] = df_csv['family_parsed'].iloc[index]

        if seg_key + fam_key not in unspc_family_full:
            unspc_family_full[seg_key + fam_key] = df_csv['family_parsed'].iloc[index]

    # class hash map
    if seg_key and fam_key and class_key:
        if seg_key not in unspc_class:
            unspc_class[seg_key][fam_key][class_key] = df_csv['class_parsed'].iloc[index]
        elif fam_key not in unspc_class[seg_key]:
            unspc_class[seg_key][fam_key][class_key] = df_csv['class_parsed'].iloc[index]
        elif class_key not in unspc_class[seg_key][fam_key]:
            unspc_class[seg_key][fam_key][class_key] = df_csv['class_parsed'].iloc[index]

        if seg_key + fam_key + class_key not in unspc_class_full:
            unspc_class_full[seg_key + fam_key + class_key] = df_csv['class_parsed'].iloc[index]

    # commodity hash map
    if seg_key and fam_key and class_key and com_key:
        if seg_key not in unspc_class:
            unspc_commodity[seg_key][fam_key][class_key][com_key] = df_csv['commodity_parsed'].iloc[index]
        elif fam_key not in unspc_commodity[seg_key]:
            unspc_commodity[seg_key][fam_key][class_key][com_key] = df_csv['commodity_parsed'].iloc[index]
        elif class_key not in unspc_commodity[seg_key][fam_key]:
            unspc_commodity[seg_key][fam_key][class_key][com_key] = df_csv['commodity_parsed'].iloc[index]
        elif com_key not in unspc_commodity[seg_key][fam_key][class_key]:
            unspc_commodity[seg_key][fam_key][class_key][com_key] = df_csv['commodity_parsed'].iloc[index]

        if seg_key + fam_key + class_key + com_key not in unspc_class_full:
            unspc_commodity_full[seg_key + fam_key + class_key + com_key] = df_csv['commodity_parsed'].iloc[index]

with open("segments.json", "w") as outfile:
    json.dump(unspc_segments, outfile)

with open("family.json", "w") as outfile:
    json.dump(unspc_family, outfile)

with open("class.json", "w") as outfile:
    json.dump(unspc_class, outfile)

with open("commodity.json", "w") as outfile:
    json.dump(unspc_commodity, outfile)

# print(json.dumps(unspc_segments, sort_keys=True, indent=2))
# print(json.dumps(unspc_family, sort_keys=True, indent=2))
# print(json.dumps(unspc_class, sort_keys=True, indent=2))
# print(json.dumps(unspc_commodity, sort_keys=True, indent=2))

# %%
# unspc_segments
# unspc_family
# unspc_class
# unspc_commodity
new_column_series = []

segment_best_matches = {}
family_best_matches = {}
class_best_matches = {}
commodity_best_matches = {}

for segment_key, segment_keywords in unspc_segments.items():
    for index, keyword_arr_avalara in enumerate((df_xlsx["tax_parsed"])):
        num_matches = len(np.intersect1d(keyword_arr_avalara, segment_keywords))
        if num_matches > 1:
            tax_code = df_xlsx["AvaTax System Tax Code"].iloc[index]
            if segment_key in segment_best_matches:
                segment_best_matches[segment_key].append(tax_code)
            else:
                segment_best_matches[segment_key] = [tax_code]

for family_key, family_keywords in unspc_family_full.items():
    for index, keyword_arr_avalara in enumerate((df_xlsx["tax_parsed"])):
        num_matches = len(np.intersect1d(keyword_arr_avalara, family_keywords))
        if num_matches > 0:
            tax_code = df_xlsx["AvaTax System Tax Code"].iloc[index]
            if family_key in family_best_matches:
                family_best_matches[family_key].append(tax_code)
            else:
                family_best_matches[family_key] = [tax_code]

for class_key, class_keywords in unspc_class_full.items():
    for index, keyword_arr_avalara in enumerate((df_xlsx["tax_parsed"])):
        num_matches = len(np.intersect1d(keyword_arr_avalara, class_keywords))
        if num_matches > 0:
            tax_code = df_xlsx["AvaTax System Tax Code"].iloc[index]
            if class_key in class_best_matches:
                class_best_matches[class_key].append(tax_code)
            else:
                class_best_matches[class_key] = [tax_code]

for commodity_key, commodity_keywords in unspc_commodity_full.items():
    for index, keyword_arr_avalara in enumerate((df_xlsx["tax_parsed"])):
        num_matches = len(np.intersect1d(keyword_arr_avalara, commodity_keywords))
        if num_matches > 0:
            tax_code = df_xlsx["AvaTax System Tax Code"].iloc[index]
            if commodity_key in commodity_best_matches:
                commodity_best_matches[commodity_key].append(tax_code)
            else:
                commodity_best_matches[commodity_key] = [tax_code]

print(segment_best_matches)
print(family_best_matches)
print(class_best_matches)
print(commodity_best_matches)





    # df.insert(df.shape[1], new_col, new_column_series)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 14
#      12 for segment_key, segment_keywords in unspc_segments.items():
#      13     for index, keyword_arr_avalara in enumerate((df_xlsx["tax_parsed"])):
# ---> 14         num_matches = len(np.intersect1d(keyword_arr_avalara, segment_keywords))
#      15         if num_matches > 1:
#      16             tax_code = df_xlsx["AvaTax System Tax Code"].iloc[index]
#
# NameError: name 'np' is not defined
